# %% [markdown]
# # CRYSTAL VS MODEL

# %%
import os
import pandas as pd
import os
import subprocess
import re
os.chdir("/Users/alexascunceparis/Desktop/TCR/AF3-TCRpMHC")

# %% [markdown]
# ## ANNOTATION

# %%
import os
import subprocess
from pathlib import Path

MEMORY = "5G"

def run_mir(pdb_dir,
            mir_path="./mir-1.0-SNAPSHOT.jar",
            output_dir="mir_output",
            arg="annotate-structures",  
            print_log=True):
    
    pdb_dir = Path(pdb_dir)
    pdb_list = list(pdb_dir.glob("*"))
    pdb_paths = " ".join(str(p) for p in pdb_list)

    # Crear el directorio de salida
    output_dir_path = output_dir
    os.makedirs(output_dir_path, exist_ok=True)

    cmd = f"java -Xmx{MEMORY} -cp {mir_path} com.milaboratory.mir.scripts.Examples {arg} -I {pdb_paths} -O {output_dir_path}/"

    try:
        result = subprocess.run(cmd, shell=True, check=True,
                                stdout=(None if print_log else subprocess.DEVNULL),
                                stderr=(None if print_log else subprocess.DEVNULL))
    except subprocess.CalledProcessError as e:
        raise RuntimeError(f"Failed to execute '{cmd}'") from e

# Verificar versión de Java
subprocess.run("java -version", shell=True)

pdb_dir = "./structures/crystals_pdb/"
output_dir = "./structures/structures_annotation/"

run_mir(pdb_dir=pdb_dir, output_dir=output_dir, arg="annotate-structures")

# %%
def parse_general_file(general_file):
    """
    Parses the general file and creates a dictionary mapping PDB IDs to specific chain information
    such as 'tcra_chain', 'tcrb_chain', 'peptide_chain', and 'mhc_chain'.
    
    :param general_file: Path to the general file.
    :return: A dictionary where keys are PDB IDs and values are dictionaries with chain information
    """
    # Read the general file into a pandas DataFrame
    df = pd.read_csv(general_file, sep='\t')
    pdb_dict = {}

    # Group by PDB ID and iterate through each group
    for pdb_id, group in df.groupby('pdb.id'):
        pdb_id = pdb_id.split('.')[0]  # Extract the PDB ID from the first part of the string
        chains = {
            'tcra_chain': None,
            'tcrb_chain': None,
            'peptide_chain': None,
            'mhc_chain': None
        }

        # Iterate through the rows in the group to assign chain types
        for _, row in group.iterrows():
            chain_id = row['chain.id']
            chain_type = row['chain.type']
            chain_component = row['chain.component']
            chain_supertype = row['chain.supertype']

            # Assign chain IDs based on their component and type
            if chain_component == 'TCR' and chain_type == 'TRA':
                chains['tcra_chain'] = chain_id
            elif chain_component == 'TCR' and chain_type == 'TRB':
                chains['tcrb_chain'] = chain_id
            elif chain_component == 'PEPTIDE':
                chains['peptide_chain'] = chain_id
            elif chain_component == 'MHC' and chain_supertype == 'MHCI' and chain_type == 'MHCa':
                chains['mhc_chain'] = chain_id
            elif chain_component == 'MHC' and chain_supertype == 'MHCI' and chain_type == 'MHCb':
                chains['b2_chain'] = chain_id
        
        # Add the chain information for this pdb_id to the dictionary
        pdb_dict[pdb_id] = chains

    return pdb_dict

chain_dict = parse_general_file('./structures/structures_annotation/general.txt')

# %% [markdown]
# # UTILS

# %% [markdown]
# - Cif to PDB with pymol
# - Cif to PDB with BeEM
# - Remove Headers, Hetatm...
# - Remove Residues with letter (e.g 116A)
# - Merge chains A (TCR), B (pMHC)

# %%
import os
import subprocess

def convert_cif_to_pdb_BeEM(input_dir, pdb_dir):
    """
    Converts CIF files located in nested seed folders to PDB format using BeEM.
    
    - input_dir: str, root folder containing 4-letter PDB ID folders
    - pdb_dir: str, output folder for resulting PDB files
    """
    beem_path = "./BeEM/BeEM"
    os.makedirs(pdb_dir, exist_ok=True)

    for folder in os.listdir(input_dir):
        if len(folder) == 4:  # Typical PDB ID
            pdb_id = folder
            folder_path = os.path.join(input_dir, folder)

            for folder2 in os.listdir(folder_path):
                if folder2.startswith("seed"):
                    model_number = folder2.split("-")[-1]
                    cif_path = os.path.join(folder_path, folder2, "model.cif")
                    output_path = os.path.join(pdb_dir, f"{pdb_id}_{model_number}.pdb")

                    if not os.path.exists(cif_path):
                        print(f"Missing CIF file: {cif_path}. Skipping.")
                        continue

                    command = f"{beem_path} -p={output_path} {cif_path}"
                    try:
                        subprocess.run(command, shell=True, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
                        print(f"Converted {cif_path} → {output_path}")
                    except subprocess.CalledProcessError as e:
                        print(f"Error converting {cif_path}: {e}")

def convert_cif_to_pdb(input_dir, pdb_dir):
    # Create folders 
    os.makedirs(pdb_dir, exist_ok=True)

    for folder in os.listdir(input_dir):
        if len(folder) == 4:  # PDB ID
            pdb_id = folder
            for folder2 in os.listdir(os.path.join(input_dir, folder)):
                if folder2.startswith("seed"):
                    model_number = folder2.split("-")[-1]
                    cif_file = "model.cif"
                    cif_path = os.path.join(input_dir, folder, folder2, cif_file)
                    output_path = os.path.join(pdb_dir, f"{pdb_id}_{model_number}.pdb")

                    pymol_command = f"pymol -c -d 'load {cif_path}; save {output_path}'"
                    try:
                        subprocess.run(pymol_command, shell=True, check=True)
                        print(f"Converted {cif_path} → {output_path}")
                    except subprocess.CalledProcessError as e:
                        print(f"Error converting {cif_file}: {e}")

def clean_pdb_file(pdb_file_path, output_file_path):
    with open(pdb_file_path, "r") as infile:
        lines = infile.readlines()

    cleaned_lines = []
    for line in lines:
        if line.startswith("ATOM"):
            residue_number = line[22:27].strip()
            # Exclude residue numbers with letter suffix
            if residue_number[-1].isalpha():
                continue
            cleaned_lines.append(line)
        # Ignore HETATM and all other lines

    with open(output_file_path, "w") as outfile:
        outfile.writelines(cleaned_lines)

def clean_all_pdbs(pdb_dir, cleaned_pdb_dir):
    # Create folders
    os.makedirs(cleaned_pdb_dir, exist_ok=True)
    for pdb_file in os.listdir(pdb_dir):
        if pdb_file.endswith(".pdb"):
            pdb_path = os.path.join(pdb_dir, pdb_file)
            cleaned_pdb_path = os.path.join(cleaned_pdb_dir, pdb_file)
            clean_pdb_file(pdb_path, cleaned_pdb_path)
            print(f"Cleaned → {cleaned_pdb_path}")

def merge_chains(input_dir, output_dir, chain_dict):
    """
    Procesa archivos PDB, selecciona y renombra cadenas específicas, elimina encabezados,
    y guarda archivos PDB combinados en el directorio de salida.
    """
    def remove_headers(file_path):
        """Elimina líneas que no empiezan con 'ATOM' del archivo PDB."""
        with open(file_path, 'r') as f:
            return [line for line in f if line.startswith("ATOM")]

    os.makedirs(output_dir, exist_ok=True)

    for pdb_file in os.listdir(input_dir):
        if not pdb_file.endswith(".pdb"):
            continue

        pdb_id = pdb_file.split(".")[0]
        pdb_file_path = os.path.join(input_dir, pdb_file)

        if pdb_id not in chain_dict:
            print(f"Warning: No chain information found for {pdb_id}. Setting default chains.")
            chain_dict[pdb_id] = {
                'tcra_chain': 'D',
                'tcrb_chain': 'E',
                'peptide_chain': 'C',
                'b2_chain': 'B',
                'mhc_chain': 'A'}

        tcra_id = chain_dict[pdb_id]['tcra_chain']
        tcrb_id = chain_dict[pdb_id]['tcrb_chain']
        mhc_id  = chain_dict[pdb_id]['mhc_chain']
        b2_id   = chain_dict[pdb_id]['b2_chain']
        epitope_id = chain_dict[pdb_id]['peptide_chain']

        print(f"Processing: {pdb_file}")
        print(f"tcra: {tcra_id}, tcrb: {tcrb_id}, mhc: {mhc_id}, b2: {b2_id}, epitope: {epitope_id}")

        command_AB = f"pdb_selchain -{tcra_id},{tcrb_id} {pdb_file_path} | pdb_chain -B | pdb_reres -1 | pdb_delhetatm > B.pdb"
        command_MB = f"pdb_selchain -{mhc_id},{b2_id},{epitope_id} {pdb_file_path} | pdb_chain -A | pdb_reres -1 | pdb_delhetatm > A.pdb"

        try:
            subprocess.run(command_MB, shell=True, check=True)
            subprocess.run(command_AB, shell=True, check=True)

            A_lines = remove_headers("A.pdb")
            B_lines = remove_headers("B.pdb")

            output_file_path = os.path.join(output_dir, f"{pdb_id}_merged.pdb")
            with open(output_file_path, 'w') as outfile:
                outfile.writelines(A_lines)
                outfile.writelines(B_lines)

            os.remove("A.pdb")
            os.remove("B.pdb")

            print(f"Processed and saved merged PDB as: {output_file_path}")

        except subprocess.CalledProcessError as e:
            print(f"Error processing {pdb_file}: {e}")
            if os.path.exists(output_file_path):
                os.remove(output_file_path)

# %%
input_dir = "./structures/af3_output"

pdb_dir = "./structures/models/models_pdb"
cleaned_pdb_dir = "./structures/models/cleaned_models_pdb"
merged_models_dir = "./structures/models/merged_models"

crystal_pdb_dir = "./structures/crystals/crystals_pdb"
cleaned_crystal_pdb_dir = "./structures/crystals/cleaned_crystals_pdb"
merged_crystals_dir = "./structures/crystals/merged_crystals"

# Convert model CIF files to PDB
convert_cif_to_pdb(input_dir, pdb_dir)

# Clean model PDB files
clean_all_pdbs(pdb_dir, cleaned_pdb_dir)

# Clean crystal PDB files
clean_all_pdbs(crystal_pdb_dir, cleaned_crystal_pdb_dir)

# Merge chains in model PDB files
merge_chains(cleaned_pdb_dir, merged_models_dir, chain_dict)

# Merge chains in crystal PDB files
merge_chains(cleaned_crystal_pdb_dir, merged_crystals_dir, chain_dict)
# Out:
# Warning: No chain information found for 1oga_2. Setting default chains.
# Processing: 1oga_2.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1oga_2_merged.pdb
# Warning: No chain information found for 1mwa_2. Setting default chains.
# Processing: 1mwa_2.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1mwa_2_merged.pdb
# Warning: No chain information found for 1mwa_3. Setting default chains.
# Processing: 1mwa_3.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1mwa_3_merged.pdb
# Warning: No chain information found for 1oga_3. Setting default chains.
# Processing: 1oga_3.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1oga_3_merged.pdb
# Warning: No chain information found for 1oga_1. Setting default chains.
# Processing: 1oga_1.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1oga_1_merged.pdb
# Warning: No chain information found for 1mwa_1. Setting default chains.
# Processing: 1mwa_1.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1mwa_1_merged.pdb
# Warning: No chain information found for 1mwa_0. Setting default chains.
# Processing: 1mwa_0.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1mwa_0_merged.pdb
# Warning: No chain information found for 1oga_0. Setting default chains.
# Processing: 1oga_0.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1oga_0_merged.pdb
# Warning: No chain information found for 1oga_4. Setting default chains.
# Processing: 1oga_4.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1oga_4_merged.pdb
# Warning: No chain information found for 1mwa_4. Setting default chains.
# Processing: 1mwa_4.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1mwa_4_merged.pdb
# Warning: No chain information found for 1g6r_1. Setting default chains.
# Processing: 1g6r_1.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1g6r_1_merged.pdb
# Warning: No chain information found for 1g6r_0. Setting default chains.
# Processing: 1g6r_0.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1g6r_0_merged.pdb
# Warning: No chain information found for 1ao7_4. Setting default chains.
# Processing: 1ao7_4.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1ao7_4_merged.pdb
# Warning: No chain information found for 1g6r_2. Setting default chains.
# Processing: 1g6r_2.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1g6r_2_merged.pdb
# Warning: No chain information found for 1g6r_3. Setting default chains.
# Processing: 1g6r_3.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1g6r_3_merged.pdb
# Warning: No chain information found for 1ao7_1. Setting default chains.
# Processing: 1ao7_1.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1ao7_1_merged.pdb
# Warning: No chain information found for 1ao7_0. Setting default chains.
# Processing: 1ao7_0.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1ao7_0_merged.pdb
# Warning: No chain information found for 1g6r_4. Setting default chains.
# Processing: 1g6r_4.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1g6r_4_merged.pdb
# Warning: No chain information found for 1ao7_2. Setting default chains.
# Processing: 1ao7_2.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1ao7_2_merged.pdb
# Warning: No chain information found for 1ao7_3. Setting default chains.
# Processing: 1ao7_3.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1ao7_3_merged.pdb
# Warning: No chain information found for 1nam_1. Setting default chains.
# Processing: 1nam_1.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1nam_1_merged.pdb
# Warning: No chain information found for 1fo0_0. Setting default chains.
# Processing: 1fo0_0.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1fo0_0_merged.pdb
# Warning: No chain information found for 1lp9_2. Setting default chains.
# Processing: 1lp9_2.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1lp9_2_merged.pdb
# Warning: No chain information found for 1bd2_3. Setting default chains.
# Processing: 1bd2_3.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1bd2_3_merged.pdb
# Warning: No chain information found for 1lp9_3. Setting default chains.
# Processing: 1lp9_3.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1lp9_3_merged.pdb
# Warning: No chain information found for 1bd2_2. Setting default chains.
# Processing: 1bd2_2.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1bd2_2_merged.pdb
# Warning: No chain information found for 1fo0_1. Setting default chains.
# Processing: 1fo0_1.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1fo0_1_merged.pdb
# Warning: No chain information found for 1nam_0. Setting default chains.
# Processing: 1nam_0.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1nam_0_merged.pdb
# Warning: No chain information found for 1kj2_4. Setting default chains.
# Processing: 1kj2_4.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1kj2_4_merged.pdb
# Warning: No chain information found for 1nam_2. Setting default chains.
# Processing: 1nam_2.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1nam_2_merged.pdb
# Warning: No chain information found for 1bd2_0. Setting default chains.
# Processing: 1bd2_0.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1bd2_0_merged.pdb
# Warning: No chain information found for 1lp9_1. Setting default chains.
# Processing: 1lp9_1.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1lp9_1_merged.pdb
# Warning: No chain information found for 1fo0_3. Setting default chains.
# Processing: 1fo0_3.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1fo0_3_merged.pdb
# Warning: No chain information found for 1fo0_2. Setting default chains.
# Processing: 1fo0_2.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1fo0_2_merged.pdb
# Warning: No chain information found for 1bd2_1. Setting default chains.
# Processing: 1bd2_1.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1bd2_1_merged.pdb
# Warning: No chain information found for 1lp9_0. Setting default chains.
# Processing: 1lp9_0.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1lp9_0_merged.pdb
# Warning: No chain information found for 1nam_3. Setting default chains.
# Processing: 1nam_3.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1nam_3_merged.pdb
# Warning: No chain information found for 1kj2_3. Setting default chains.
# Processing: 1kj2_3.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1kj2_3_merged.pdb
# Warning: No chain information found for 1lp9_4. Setting default chains.
# Processing: 1lp9_4.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1lp9_4_merged.pdb
# Warning: No chain information found for 1bd2_4. Setting default chains.
# Processing: 1bd2_4.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1bd2_4_merged.pdb
# Warning: No chain information found for 1kj2_2. Setting default chains.
# Processing: 1kj2_2.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1kj2_2_merged.pdb
# Warning: No chain information found for 1kj2_0. Setting default chains.
# Processing: 1kj2_0.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1kj2_0_merged.pdb
# Warning: No chain information found for 1nam_4. Setting default chains.
# Processing: 1nam_4.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1nam_4_merged.pdb
# Warning: No chain information found for 1fo0_4. Setting default chains.
# Processing: 1fo0_4.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1fo0_4_merged.pdb
# Warning: No chain information found for 1kj2_1. Setting default chains.
# Processing: 1kj2_1.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1kj2_1_merged.pdb
# Warning: No chain information found for 1mi5_0. Setting default chains.
# Processing: 1mi5_0.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1mi5_0_merged.pdb
# Warning: No chain information found for 1mi5_1. Setting default chains.
# Processing: 1mi5_1.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1mi5_1_merged.pdb
# Warning: No chain information found for 1mi5_3. Setting default chains.
# Processing: 1mi5_3.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1mi5_3_merged.pdb
# Warning: No chain information found for 1mi5_2. Setting default chains.
# Processing: 1mi5_2.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1mi5_2_merged.pdb
# Warning: No chain information found for 1mi5_4. Setting default chains.
# Processing: 1mi5_4.pdb
# tcra: D, tcrb: E, mhc: A, b2: B, epitope: C
# Processed and saved merged PDB as: ./structures/merged_models/1mi5_4_merged.pdb

# %% [markdown]
# # CRYSTAL VS MODEL

# %%
from Bio import PDB
from Bio.PDB import PDBParser, MMCIFParser
from Bio.Align import PairwiseAligner
from Bio.SVDSuperimposer import SVDSuperimposer
import numpy as np
import os
import pandas as pd
import subprocess
import re
import argparse

residue_mapping = {
    'ALA': 'A', 'ARG': 'R', 'ASN': 'N', 'ASP': 'D',
    'CYS': 'C', 'GLU': 'E', 'GLN': 'Q', 'GLY': 'G',
    'HIS': 'H', 'ILE': 'I', 'LEU': 'L', 'LYS': 'K',
    'MET': 'M', 'PHE': 'F', 'PRO': 'P', 'SER': 'S',
    'THR': 'T', 'TRP': 'W', 'TYR': 'Y', 'VAL': 'V'}

# RMSD functions -----------------------------------------------------------
def cif_to_pdb(cif_file):
    """
    Converts a single CIF file to PDB format and saves it in the same folder with the same name.
    
    Parameters:
    - cif_file: str, path to the input CIF file.
    """
    # Define the output PDB file path (same folder, same name, .pdb extension)
    pdb_file = os.path.splitext(cif_file)[0]
    beem_path = "../../data_augmentation/BeEM/BeEM"#"/gpfs/projects/bsc72/aascunce/data_augmentation/BeEM/BeEM"
    # Build the PyMOL command to convert CIF to PDB
    command = f"{beem_path} -p={pdb_file} {cif_file}"

    # Suppress the output of the pymol command by redirecting stdout and stderr to os.devnull
    try:
        with open(os.devnull, 'w') as devnull:
            subprocess.run(command, shell=True, stdout=devnull, stderr=devnull, check=True)
        print(f"Successfully converted {cif_file} to {pdb_file}")
    except subprocess.CalledProcessError as e:
        # Handle errors during the conversion process
        print(f"Error converting {cif_file}: {e}")

def merge_pdb(pdb_file):
    """
    Processes a single PDB file, modifies chain IDs, and merges the results into a single PDB file.

    Parameters:
    - pdb_file: str, path to the input PDB file.

    Output:
    - A merged PDB file with the same name as the input, appended with '_merged', saved in the same directory.
    """
    # Define chain IDs
    tcra_id = "D"
    tcrb_id = "E"
    mhc_id = "A"
    b2_id = "B"
    epitope_id = "C"

    # Extract base name and define output file path
    base_name = pdb_file.rsplit(".", 1)[0]  # Name without extension
    output_file_path = f"{base_name}_merged.pdb"  # Add '_merged' to the output file name

    # Preprocess the input file to remove invalid lines and save a temporary cleaned file
    cleaned_pdb_file = f"{base_name}_cleaned.pdb"
    cleaned_lines = remove_headers(pdb_file)
    with open(cleaned_pdb_file, 'w') as cleaned_file:
        cleaned_file.writelines(cleaned_lines)

    # Construct shell commands
    command_AB = (
        f"pdb_selchain -{tcra_id},{tcrb_id} {cleaned_pdb_file} "
        f"| pdb_chain -B | pdb_reres -1 | pdb_delhetatm > B.pdb"
    )
    command_MB = (
        f"pdb_selchain -{mhc_id},{b2_id},{epitope_id} {cleaned_pdb_file} "
        f"| pdb_chain -A | pdb_reres -1 | pdb_delhetatm > A.pdb"
    )

    try:
        # Execute shell commands to generate temporary files
        subprocess.run(command_MB, shell=True, check=True)
        subprocess.run(command_AB, shell=True, check=True)

        # Remove headers and merge the files
        A_lines = remove_headers("A.pdb")
        B_lines = remove_headers("B.pdb")

        # Save the merged PDB file
        with open(output_file_path, 'w') as outfile:
            outfile.writelines(A_lines)
            outfile.writelines(B_lines)

        # Clean up temporary files
        os.remove('A.pdb')
        os.remove('B.pdb')
        os.remove(cleaned_pdb_file)

    except subprocess.CalledProcessError as e:
        print(f"Error processing {pdb_file}: {e}")

def remove_headers(file_path):
    """
    Remove non-ATOM/HETATM lines from a PDB file and validate line length.

    Parameters:
    - file_path: str, path to the PDB file.

    Returns:
    - List of cleaned lines (ATOM/HETATM and properly formatted).
    """
    cleaned_lines = []
    with open(file_path, 'r') as file:
        for line in file:
            # Keep only ATOM/HETATM lines with sufficient length
            if (line.startswith("ATOM") or line.startswith("HETATM")) and len(line) > 21:
                cleaned_lines.append(line)
    return cleaned_lines

def extract_sequences(pdb_file):
    """
    Extract sequences for all chains from a PDB file in two forms:
    - A dictionary of sequences as single-letter residue codes (string).
    - A dictionary of sequences as lists of (resname, resid) tuples.
    
    Returns:
    - sequences_str (dict): A dictionary with chain_id as key and sequence as string of 1-letter codes.
    - sequences_tuples (dict): A dictionary with chain_id as key and sequence as list of tuples (resname, resid).
    """
    if pdb_file.endswith(".pdb"):
        parser = PDB.PDBParser(QUIET=True)
        structure = parser.get_structure('structure', pdb_file)
    else:
        parser=PDB.MMCIFParser(QUIET=True)
        structure = parser.get_structure('structure', pdb_file)
    
    sequences_str = {}
    sequences_tuples = {}

    for model in structure:
        for chain in model.get_chains():
            chain_id = chain.get_id()
            sequence_str = []  # For single-letter sequence
            sequence_tuples = []  # For (resname, resid) tuples
            for residue in chain:
                if PDB.is_aa(residue):  # Ensure the residue is an amino acid
                    res_name = residue.get_resname()  
                    resid = residue.get_id()[1]  # Residue ID
                    # Add the single-letter residue code to the string
                    sequence_str.append(residue_mapping.get(res_name, 'X'))  # 'X' if unknown residue
                    # Store the (resname, resid) tuple for residue identity
                    sequence_tuples.append((res_name, resid))  
            sequences_str[chain_id] = ''.join(sequence_str)  # Join into string
            sequences_tuples[chain_id] = sequence_tuples  # Store the tuples
    return sequences_str, sequences_tuples


def align_sequences(seqA, seqB):
    """
    Align two sequences using pairwise sequence alignment and return the aligned sequences with residue info.
    """
    aligner = PairwiseAligner()
    aligner.match = 5
    aligner.mismatch = -1
    aligner.open_gap_score = -4
    aligner.extend_gap_score = -1
    aln = aligner.align(seqA, seqB)[0]
    return aln

def format_alignment(aln, chain_id_cry, chain_id_mod, dict_cry, dict_mode):
    """
    Format the alignment and return the residue names and IDs for each sequence in the alignment.
    Also return the matches as before ('|' for match, '.' for mismatch, ' ' for gap).
    """
    aligned_residues = {'seqA': [], 'seqB': [], 'matches': []}
    seqA_aligned = aln[0, :]
    seqB_aligned = aln[1, :]
    indexA = 0
    indexB = 0
    for i in range(len(seqA_aligned)):
        if seqA_aligned[i] != '-':
            res_nameA, res_idA = dict_cry[chain_id_cry][indexA] 
            aligned_residues['seqA'].append((res_nameA, res_idA))
            indexA += 1
        else:
            aligned_residues['seqA'].append(('-', '-'))

        if seqB_aligned[i] != '-':
            res_nameB, res_idB = dict_mode[chain_id_mod][indexB] 
            aligned_residues['seqB'].append((res_nameB, res_idB))
            indexB += 1
        else:
            aligned_residues['seqB'].append(('-', '-'))

        if seqA_aligned[i] == seqB_aligned[i]:
            aligned_residues['matches'].append('|')  
        elif seqA_aligned[i] == '-' or seqB_aligned[i] == '-':
            aligned_residues['matches'].append(' ')  
        else:
            aligned_residues['matches'].append('.')  
    return aligned_residues

def get_aligned_residues(alignment):
    """
    Map aligned residues from two chains based on a given sequence alignment.
    Only returns residues that are matches, formatted as (resname, resid_crystal, resid_model).
    """
    aligned_residues = []
    seqA_aligned = alignment["seqA"]
    seqB_aligned = alignment["seqB"]
    matches = alignment["matches"]
    indexA = 0
    indexB = 0
    for i in range(len(seqA_aligned)):
        if seqA_aligned[i] != "-" and seqB_aligned[i] != "-" and matches[i] == "|":
            res_nameA, resid_crystal = seqA_aligned[i]
            res_nameB, resid_model = seqB_aligned[i]
            aligned_residues.append((res_nameA, resid_crystal, resid_model))
            indexA += 1
            indexB += 1
    return aligned_residues

def get_interface(pdb_file, reference_chain, chain_ids, distance_cutoff=10.0, select_heavy_atoms=False):
    """
    Select Cα atoms from chains A, B, and C that are within a certain distance (default: 10 Å)
    from any atom of chain C, and also include all Cα atoms from chain C. Optionally, select heavy atoms.

    Args:
    - pdb_file (str): Path to the PDB file.
    - reference_chain (str): The chain ID of the reference chain (usually chain C).
    - chain_ids (list of str): List of chain IDs to select atoms from, including 'A', 'B', and 'C'.
    - distance_cutoff (float): Distance cutoff in Å (default 10 Å).
    - select_heavy_atoms (bool): If True, select all heavy atoms (default: False).

    Returns:
    - selected_atoms (list of tuples): A list of atoms (atom name, residue ID, residue name, and chain ID)
      that are within the distance cutoff from atoms in chain C, plus all Cα atoms from chain C (or all heavy atoms if specified).
    """
    parser = PDB.PDBParser(QUIET=True)
    structure = parser.get_structure('structure', pdb_file)
    selected_atoms = []
    chain_ref_atoms = []
    chain_others_atoms = []
    for model in structure:
        for chain in model.get_chains():
            chain_id = chain.get_id()
            if chain_id == reference_chain:
                for residue in chain:
                    for atom in residue:
                        chain_ref_atoms.append(atom)
            if chain_id in chain_ids:
                for residue in chain:
                    for atom in residue:
                        if select_heavy_atoms:
                            if atom.element != 'H':
                                chain_others_atoms.append((atom, residue.get_id()[1], residue.get_resname(), chain_id))
                        else:
                            if atom.get_name() == "CA":
                                chain_others_atoms.append((atom, residue.get_id()[1], residue.get_resname(), chain_id))
    for atom, resid, resname, chain_id in chain_others_atoms:
        for ref_atom in chain_ref_atoms:
            distance = atom - ref_atom
            if distance <= distance_cutoff:
                selected_atoms.append((atom.get_name(), resid, resname, chain_id))
    for atom in chain_others_atoms:
        atom_obj, resid, resname, chain_id = atom
        if chain_id == reference_chain:  # Only add atoms from chain C
            selected_atoms.append((atom_obj.get_name(), resid, resname, chain_id))
    return selected_atoms

def get_atom_coordinates(pdb_file, selected_atoms):
    if pdb_file.endswith(".pdb"):
        parser = PDB.PDBParser(QUIET=True)
    else:
        parser = PDB.MMCIFParser(QUIET=True)
    
    structure = parser.get_structure('structure', pdb_file)
    coordinates = []

    for atom_name, resid, resname, chain_id in selected_atoms:
        try:
            chain = structure[0][chain_id]
            residue = chain[resid]
            found = False
            for atom in residue:
                if atom.get_name() == atom_name:
                    coordinates.append(atom.get_coord())
                    found = True
                    break
            if not found:
                print(f"Warning: Atom {atom_name} in residue {resid} of chain {chain_id} not found.")
        except KeyError:
            print(f"Warning: Chain {chain_id} or residue {resid} not found in the structure.")

    if not coordinates:
        raise ValueError(f"No coordinates found for the selected atoms: {selected_atoms}")

    coordinates_array = np.array(coordinates, dtype='f')
    return coordinates_array

# ANARCI and parsing functions -----------------------------------------------------------
def extract_residues_and_resids(pdb_file, chain_id):
    """
    Extract the residue IDs and residues (in one-letter code) from a specific chain in a PDB file.
    
    Args:
        pdb_file (str): Path to the PDB file.
        chain_id (str): Chain ID to extract residues from.
    
    Returns:
        list of tuples: List of tuples where each tuple contains (resid, residue_one_letter).
    """
    if pdb_file.endswith(".pdb"):
        parser = PDB.PDBParser(QUIET=True)
        structure = parser.get_structure('structure', pdb_file)
    else:
        parser=PDB.MMCIFParser(QUIET=True)
        structure = parser.get_structure('structure', pdb_file)
        
    residues = []
    for model in structure:
        for chain in model:
            if chain.id == chain_id:
                for residue in chain:
                    resid = residue.get_id()[1]
                    resname = residue.get_resname()
                    residue_one_letter = PDB.Polypeptide.protein_letters_3to1.get(resname, 'X')  # Use 'X' for unknown residues
                    residues.append((resid, residue_one_letter))
    
    return residues

def run_anarci(sequence):
    """
    Execute ANARCI to assign IMGT numbering to a TCR sequence.
    """
    try:
        command=f"ANARCI -i {sequence} --scheme imgt"
        result = subprocess.run(command, shell=True, capture_output=True, text=True, check=True)
        return result.stdout
    except subprocess.CalledProcessError as e:
        return f"Error: {e.stderr}"
    
import re

def parse_anarci_output(anarci_output):
    """
    Parse the output of ANARCI to extract IMGT numbering and residues, ensuring uniqueness of IMGT numbers.
    
    Args:
        anarci_output (str): Output from ANARCI as a string.
    
    Returns:
        list of tuples: A list where each tuple contains (IMGT_number, residue) with unique IMGT numbers.
    """
    pattern = r'^([A-Z])\s+(\d+)\s+([A-Z\-])'
    matches = re.findall(pattern, anarci_output, re.MULTILINE)
    
    imgt_numbered_seq = []
    seen_imgt_numbers = set()
    
    for match in matches:
        try:
            chain_letter, imgt_num, residue = match
            imgt_num = int(imgt_num)
            
            # Ensure uniqueness of IMGT numbers
            if imgt_num not in seen_imgt_numbers:
                imgt_numbered_seq.append((imgt_num, residue))
                seen_imgt_numbers.add(imgt_num)
        except ValueError as e:
            print(f"Error processing match: {match}. Error: {e}")
    
    return imgt_numbered_seq

def map_imgt_to_original(imgt_numbered_seq, pdb_resids):
    """
    Map the original numbering of a sequence from the PDB 'resids' to the IMGT numbering.
    
    Args:
        imgt_numbered_seq (list of tuples): The IMGT numbered sequence as tuples (IMGT_number, residue).
        pdb_resids (list of tuples): The original residue numbers from the PDB file as tuples (resid, residue_one_letter).
    
    Returns:
        list of tuples: A list where each tuple contains (original_resid, IMGT_number, residue).
    """
    mapping = []
    pdb_resid_index = 0  # Index for PDB residues
    
    for imgt_pos, residue in imgt_numbered_seq:
        if residue != "-":  # Only process non-gap residues in IMGT
            for original_resid, residue1 in pdb_resids[pdb_resid_index:]:
                if residue1 == residue:
                    mapping.append((original_resid, imgt_pos, residue))
                    pdb_resid_index += 1
                    break
                else:
                    pdb_resid_index += 1
            else:
                mapping.append((None, imgt_pos, residue))
        else:
            mapping.append((None, imgt_pos, residue))
    return mapping

def parse_CDR3 (mapping):
    cdr3_tuples = [tupple for tupple in mapping if 105 <= tupple[1] <= 117 and tupple[2] != "-"]
    return cdr3_tuples

def parse_CDR2 (mapping):
    cdr2_tuples = [tupple for tupple in mapping if 56 <= tupple[1] <= 65 and tupple[2] != "-"]
    return cdr2_tuples

def parse_CDR1 (mapping):
    cdr1_tuples = [tupple for tupple in mapping if 27 <= tupple[1] <= 38 and tupple[2] != "-"]
    return cdr1_tuples

def extract_atoms_for_cdr(cdr_list, pdb_file, chain_id):
    """
    Extract atoms of the residues of a CDR from a PDB file.
    
    :param cdr_list: List of tuples in the format (resid, imgtid, resname)
    :param pdb_file: Path to the PDB file of the structure
    :param chain_id: Chain ID (e.g., 'A', 'B') to extract the atoms from
    :return: List of tuples with the format (atomname, resid, resname, chain_id)
    """
    if pdb_file.endswith(".pdb"):
        parser = PDB.PDBParser(QUIET=True)
    else:
        parser=PDB.MMCIFParser(QUIET=True)
    structure = parser.get_structure('structure', pdb_file)
    atom_list = [] 
    for model in structure:
        for chain in model:
            if chain.id == chain_id:  
                for residue in chain:
                    resid = residue.get_id()[1]  
                    resname_3 = residue.get_resname() 
                    resname_1 = residue_mapping.get(resname_3, 'X')
                    for cdr_resid, cdr_imgtid, cdr_resname in cdr_list:
                        if resid == cdr_resid and resname_1 == cdr_resname:
                            for atom in residue:
                                atom_list.append((atom.get_name(), resid, resname_3, chain.id))
    return atom_list

def calculate_rmsd(crystal_pdb, model_pdb, pdb_id, chain_dict, distance_cutoff=10.0):
    """
    Calculate RMSD between a crystal and a model structure for all chains.

    Args:
        crystal_pdb (str): Path to the crystal structure PDB file.
        model_pdb (str): Path to the model structure PDB file.
        chain_ids (list): List of chain IDs to consider for the interface (default ['A', 'B', 'C']).
        distance_cutoff (float): Distance cutoff for selecting interface residues (default 10.0 Å).

    Returns:
        dict: Overall RMSD and chain-specific RMSD details.
    """
    
    # Step 1: Parse structures and extract sequences
    if model_pdb.endswith(".pdb"):
        parser = PDBParser(QUIET=True)
    else:
        parser = MMCIFParser(QUIET=True)
    model_structure = parser.get_structure("model", model_pdb)

    # Extract sequences and map residues
    crystal_sequences, dict_cry = extract_sequences(crystal_pdb)
    model_sequences, dict_mod = extract_sequences(model_pdb)
    chain_dict=chain_dict[pdb_id]
    mapping = []

    if len(model_sequences) == 5:
        model_chain_mapping = {
            'mhc_chain':'A',
            'b2_chain':'B',
            'peptide_chain':'C',
            'tcra_chain':'D',
            'tcrb_chain':'E'}
        
    elif len(model_sequences) == 4:
        model_chain_mapping = {
            'mhc_chain':'A',
            'peptide_chain':'B',
            'tcra_chain':'C',
            'tcrb_chain':'D'}
    else:
        print(f"Error: Model structure does not have 4 or 5 chains.")

    # Step 2: Loop over chains to align sequences
    for chain_crystal, seq_crystal in crystal_sequences.items():
        key = next((key for key, value in chain_dict.items() if value == chain_crystal), None)
        if key is not None:
            model_id = model_chain_mapping.get(key)
            if model_id in model_sequences:
                seq_model = model_sequences[model_id]
                alignment = align_sequences(seq_crystal, seq_model)
                formatted_alignment = format_alignment(alignment, chain_crystal, model_id, dict_cry, dict_mod)
                aligned_residues = get_aligned_residues(formatted_alignment)
                aligned_residues = [res + (f'{chain_crystal}',) for res in aligned_residues]
                mapping.extend(aligned_residues)
            else:
                print(f"Error: {model_id} not in model_sequences.")
        else:
            print(f"Error: {chain_crystal} not in chain_dict.")

    # Step 3: Select interface atoms
    reference_chain = chain_dict['peptide_chain']
    if len(model_sequences) == 5:
        chain_ids = [chain_dict['tcra_chain'], chain_dict['tcrb_chain'], chain_dict['peptide_chain'], chain_dict['mhc_chain'], chain_dict['b2_chain']]
    elif len(model_sequences) == 4:
        chain_ids = [chain_dict['tcra_chain'], chain_dict['tcrb_chain'], chain_dict['peptide_chain'], chain_dict['mhc_chain']]
 
    selected_atoms_crystal = sorted(set(get_interface(crystal_pdb, reference_chain, chain_ids=chain_ids, distance_cutoff=distance_cutoff, select_heavy_atoms=True)),key=lambda x: (x[3], x[1]))
    selected_atoms_model = []
    atoms_to_remove_i = []
    for atom_crystal in selected_atoms_crystal:
        atom_name_crystal, resid_crystal, resname_crystal, chain_id_crystal = atom_crystal
        found_match = False  
        for resname, resid_crystal_mapping, resid_model_mapping, chain_id_mapping in mapping:
            if resid_crystal == resid_crystal_mapping and resname_crystal == resname and chain_id_crystal == chain_id_mapping:
                chain_ident = next((key for key, value in chain_dict.items() if value == chain_id_mapping), None)
                chain_id_model = model_chain_mapping.get(chain_ident)
                chain_model = model_structure[0][chain_id_model]
                for residue_model in chain_model:
                    if residue_model.get_id()[1] == resid_model_mapping:
                        for atom_model in residue_model:
                            if atom_model.get_name() == atom_name_crystal:
                                selected_atoms_model.append((atom_model.get_name(), resid_model_mapping, resname, chain_id_model))
                                found_match = True  # Marcar como encontrado
                                break
                    if found_match:  
                        break
            if found_match:
                break
        if not found_match:
            atoms_to_remove_i.append(atom_crystal)
    selected_atoms_crystal = [atom for atom in selected_atoms_crystal if atom not in atoms_to_remove_i]

    # Step 4: Get atom coordinates
    coordinates_crystal = get_atom_coordinates(crystal_pdb, selected_atoms_crystal)
    coordinates_model = get_atom_coordinates(model_pdb, selected_atoms_model)

    # Step5: Get CDR3 residues and atoms
    residues_crystal_A=extract_residues_and_resids(crystal_pdb, chain_dict['tcra_chain'])
    residues_crystal_B=extract_residues_and_resids(crystal_pdb, chain_dict['tcrb_chain'])

    anarci_A_cry=run_anarci(crystal_sequences[chain_dict['tcra_chain']])
    anarci_B_cry=run_anarci(crystal_sequences[chain_dict['tcrb_chain']])
    
    parsed_cry_A=parse_anarci_output(anarci_A_cry)
    parsed_cry_B=parse_anarci_output(anarci_B_cry)

    map_cry_A=map_imgt_to_original(parsed_cry_A, residues_crystal_A)
    map_cry_B=map_imgt_to_original(parsed_cry_B, residues_crystal_B)
    
    cdr3_cry_A=parse_CDR3(map_cry_A)
    cdr3_cry_B=parse_CDR3(map_cry_B)
    
    cdr_atoms_cry_A = extract_atoms_for_cdr(cdr3_cry_A, crystal_pdb, chain_dict['tcra_chain'])
    cdr_atoms_cry_B = extract_atoms_for_cdr(cdr3_cry_B, crystal_pdb, chain_dict['tcrb_chain'])
    cdr_atoms_crystal = cdr_atoms_cry_A + cdr_atoms_cry_B

    cdr_atoms_model = []
    atoms_to_remove = []

    for cdr_atom_crystal in cdr_atoms_crystal:
        cdr_atom_name_crystal, cdr_resid_crystal, cdr_resname_crystal, cdr_chain_id_crystal = cdr_atom_crystal
        found_match = False 
        for cdr_resname, cdr_resid_crystal_mapping, cdr_resid_model_mapping, cdr_chain_id_mapping in mapping:
            if cdr_resid_crystal == cdr_resid_crystal_mapping and cdr_resname_crystal == cdr_resname and cdr_chain_id_crystal == cdr_chain_id_mapping:
                cdr_chain_ident = next((key for key, value in chain_dict.items() if value == cdr_chain_id_mapping), None)
                cdr_chain_id_model = model_chain_mapping.get(cdr_chain_ident)
                chain_model = model_structure[0][cdr_chain_id_model]
                for residue_model in chain_model:
                    if residue_model.get_id()[1] == cdr_resid_model_mapping:  # Match the residue ID
                        for atom_model in residue_model:
                            if atom_model.get_name() == cdr_atom_name_crystal:  # Match the atom name
                                cdr_atoms_model.append((atom_model.get_name(), cdr_resid_model_mapping, cdr_resname_crystal, cdr_chain_id_model))
                                found_match = True  # Mark as found
                                break
                        if found_match:  # Break outer loops if a match is found
                            break
                if found_match:
                    break
        if not found_match:
            atoms_to_remove.append(cdr_atom_crystal)

    cdr_atoms_crystal = [atom for atom in cdr_atoms_crystal if atom not in atoms_to_remove]

    # Perform superposition and calculate overall RMSD
    if len(coordinates_crystal) == len(coordinates_model) and len(coordinates_crystal) > 0:
        sup = SVDSuperimposer()
        sup.set(coordinates_crystal, coordinates_model)
        sup.run()
        y_on_x = sup.get_transformed()
        overall_rmsd = sup.get_rms()
    else:
        return "Error: Interface atoms mismatch. Cannot superimpose."

    # Step 6: Categorize chains and calculate RMSD
    if len(model_sequences) == 5:
        categories_crystal = {
            'TCRA/TCRB': [chain_dict['tcra_chain'], chain_dict['tcrb_chain']],
            'Peptide': [chain_dict['peptide_chain']],
            'MHC/B2M': [chain_dict['mhc_chain'], chain_dict['b2_chain']]}

        categories_model = {
            'TCRA/TCRB': [model_chain_mapping['tcra_chain'], model_chain_mapping['tcrb_chain']],
            'Peptide': [model_chain_mapping['peptide_chain']],
            'MHC/B2M': [model_chain_mapping['mhc_chain'], model_chain_mapping['b2_chain']]}
    
    elif len(model_sequences) == 4:
        categories_crystal = {
            'TCRA/TCRB': [chain_dict['tcra_chain'], chain_dict['tcrb_chain']],
            'Peptide': [chain_dict['peptide_chain']],
            'MHC': [chain_dict['mhc_chain']]}
        
        categories_model = {
            'TCRA/TCRB': [model_chain_mapping['tcra_chain'], model_chain_mapping['tcrb_chain']],
            'Peptide': [model_chain_mapping['peptide_chain']],
            'MHC': [model_chain_mapping['mhc_chain']]}
    else:
        return "Error: Model structure does not have 4 or 5 chains."

    category_crystal_coords = {category: [] for category in categories_crystal}
    category_model_coords = {category: [] for category in categories_model}
    
    for atom, coord in zip(selected_atoms_crystal, coordinates_crystal):
        chain_id = atom[3]
        for category, chains in categories_crystal.items():
            if chain_id in chains:
                category_crystal_coords[category].append(coord)
                break 

    for atom, coord in zip(selected_atoms_model, y_on_x):
        chain_id = atom[3]
        for category, chains in categories_model.items():
            if chain_id in chains:
                category_model_coords[category].append(coord)
                break  

    # Step 6: Calculate RMSD for each category
    category_rmsd_results = {}
    for category, crystal_coords in category_crystal_coords.items():
        model_coords = category_model_coords[category]
        
        # Check if coordinates are valid and have the same length
        if len(crystal_coords) > 0 and len(crystal_coords) == len(model_coords):
            # Convert to numpy arrays for easy manipulation
            crystal_coords = np.array(crystal_coords)
            model_coords = np.array(model_coords)
            
            # Calculate the difference between the coordinates
            diff = crystal_coords - model_coords
            
            # Calculate RMSD: sqrt(sum((crystal - model)^2) / N)
            rmsd = np.sqrt(np.sum(np.square(diff)) / len(crystal_coords))
            category_rmsd_results[category] = rmsd
        else:
            category_rmsd_results[category] = None

    # Prepare result string
    result_string = f"Number of CA in interface: {len(selected_atoms_crystal)}, Overall iRMSD: {overall_rmsd:.2f} angstroms\n"
    for category, rmsd in category_rmsd_results.items():
        num_atoms = len(category_crystal_coords[category])
        
        if rmsd is not None:
            result_string += f"{category}: Number of CA: {num_atoms}, iRMSD: {rmsd:.2f} angstroms\n"
        else:
            result_string += f"Category {category}: Insufficient data for RMSD calculation.\n"
    #Step 7: calculate CDR RMSD
    cdr_coords_crystal_A = get_atom_coordinates(crystal_pdb, cdr_atoms_cry_A)
    cdr_coords_crystal_B = get_atom_coordinates(crystal_pdb, cdr_atoms_cry_B)
    
    cdr_coords_model_A = []
    cdr_coords_model_B = []

    indices_to_remove_A = []
    indices_to_remove_B = []

    for idx, cdr_coord in enumerate(cdr_coords_crystal_A):
        idx_crystal = np.where(np.all(coordinates_crystal == cdr_coord, axis=1))[0]
        if len(idx_crystal) > 0:
            cdr_coords_model_A.append(y_on_x[idx_crystal[0]])
        else:
            indices_to_remove_A.append(idx)

    for idx, cdr_coord in enumerate(cdr_coords_crystal_B):
        idx_crystal = np.where(np.all(coordinates_crystal == cdr_coord, axis=1))[0]
        if len(idx_crystal) > 0:
            cdr_coords_model_B.append(y_on_x[idx_crystal[0]])
        else:
            indices_to_remove_B.append(idx)

    cdr_coords_crystal_A = np.delete(cdr_coords_crystal_A, indices_to_remove_A, axis=0)
    cdr_coords_crystal_B = np.delete(cdr_coords_crystal_B, indices_to_remove_B, axis=0)

    cdr_coords_model_A = np.array(cdr_coords_model_A)
    cdr_coords_model_B = np.array(cdr_coords_model_B)

    rmsd_cdrs = {}
    if len(cdr_coords_crystal_A) > 0 and len(cdr_coords_model_A) == len(cdr_coords_crystal_A):
        diff = cdr_coords_crystal_A - cdr_coords_model_A
        rmsd = np.sqrt(np.sum(np.square(diff)) / len(cdr_coords_crystal_A))
        rmsd_cdrs['TCRA'] = rmsd
    else:
        rmsd_cdrs['TCRA'] = None
        print("Difference in number of atoms for CDR3 in chain A")
    if len(cdr_coords_crystal_B) > 0 and len(cdr_coords_model_B) == len(cdr_coords_crystal_B):
        diff = cdr_coords_crystal_B - cdr_coords_model_B
        rmsd = np.sqrt(np.sum(np.square(diff)) / len(cdr_coords_crystal_B))
        rmsd_cdrs['TCRB'] = rmsd
    else:
        rmsd_cdrs['TCRB'] = None
        print("Difference in number of atoms for CDR3 in chain B")
    
    result_string+=f"CDR3 TCRA: {rmsd_cdrs['TCRA']:.2f} angstroms\n" if rmsd_cdrs['TCRA'] is not None else "CDR3 TCRA: Insufficient data for RMSD calculation.\n"
    result_string+=f"CDR3 TCRB: {rmsd_cdrs['TCRB']:.2f} angstroms\n" if rmsd_cdrs['TCRB'] is not None else "CDR3 TCRB: Insufficient data for RMSD calculation.\n"
    if len(model_sequences) == 5:
        return (result_string, overall_rmsd, category_rmsd_results["TCRA/TCRB"], category_rmsd_results["Peptide"], category_rmsd_results["MHC/B2M"], rmsd_cdrs.get('TCRA', None), rmsd_cdrs.get('TCRB', None))
    elif len(model_sequences) == 4:
        return (result_string, overall_rmsd, category_rmsd_results["TCRA/TCRB"], category_rmsd_results["Peptide"], category_rmsd_results["MHC"], rmsd_cdrs.get('TCRA', None), rmsd_cdrs.get('TCRB', None))

def run_dockq(model_path, native_path):
    # Ejecutar el comando DockQ
    dockq_command = f"DockQ {model_path} {native_path}"
    result = subprocess.run(dockq_command, shell=True, capture_output=True, text=True, check=True)
    
    # Obtener el texto de salida
    output = result.stdout

    # Usamos expresiones regulares para extraer las métricas
    dockq_score = re.search(r'DockQ:\s*([0-9\.]+)', output)
    irmsd = re.search(r'iRMSD:\s*([0-9\.]+)', output)
    lrmsd = re.search(r'LRMSD:\s*([0-9\.]+)', output)
    fnat = re.search(r'fnat:\s*([0-9\.]+)', output)
    clashes = re.search(r'clashes:\s*(\d+)', output)

    # Parsear los resultados
    dockq_score_val = float(dockq_score.group(1)) if dockq_score else None
    irmsd_val = float(irmsd.group(1)) if irmsd else None
    lrmsd_val = float(lrmsd.group(1)) if lrmsd else None
    fnat_val = float(fnat.group(1)) if fnat else None
    clashes_val = int(clashes.group(1)) if clashes else None

    # Retornar los valores directamente
    return dockq_score_val, irmsd_val, lrmsd_val, fnat_val, clashes_val

# %%
# Use case 

pdb_id= '1ao7'
model_number='1'

crystal_pdb = f'./structures/crystals/cleaned_crystals_pdb/{pdb_id}.pdb'
model_pdb = f'./structures/models/cleaned_models_pdb/{pdb_id}_{model_number}.pdb'

dockq_native = f'./structures/crystals/merged_crystals/{pdb_id}_merged.pdb'
dockq_model = f'./structures/models/merged_models/{pdb_id}_{model_number}_merged.pdb'


result_string, overall_rmsd, rmsd_TCRA_TCRB, rmsd_Peptide, rmsd_MHC_B2M, rmsd_CDR_TCRA, rmsd_CDR_TCRB = calculate_rmsd(crystal_pdb, model_pdb, pdb_id, chain_dict, distance_cutoff=10.0)
dockq_score, irmsd, lrmsd, fnat, clashes = run_dockq(dockq_model, dockq_native)
print(result_string)
print("Dockq score", dockq_score)
print("iRMSD", irmsd)
print("lRMSD", lrmsd)
print("fnat",fnat)
print("Clashes",clashes)
# Out:
# Number of CA in interface: 1020, Overall iRMSD: 0.96 angstroms
# TCRA/TCRB: Number of CA: 268, iRMSD: 1.70 angstroms
# Peptide: Number of CA: 77, iRMSD: 0.67 angstroms
# MHC/B2M: Number of CA: 675, iRMSD: 0.45 angstroms
# CDR3 TCRA: 0.64 angstroms
# CDR3 TCRB: 1.22 angstroms
#
# Dockq score 0.632
# iRMSD 0.736
# lRMSD 14.784
# fnat 0.843
# Clashes 0

# %%
#pdbs_4chains=['4mvb', '4ms8', '3e3q', '4n5e', '6l9l', '3tfk', '3tjh', '3e2h', '2e7l', '8d5q', '3tpu', '2oi9', '4mxq', '4n0c']

def process_pdbs(crystal_folder, model_folder):
    dataframe = pd.DataFrame()
    model_folder_pdb = os.path.join(model_folder, "cleaned_models_pdb")
    crystal_folder_pdb = os.path.join(crystal_folder, "cleaned_crystals_pdb")
    for pdb_file in os.listdir(crystal_folder_pdb):
        if pdb_file.endswith(".pdb"):  
            pdb_id = pdb_file.split(".")[0]
            #if pdb_id not in pdbs_4chains:
                #continue  
            pdb_path = os.path.join(crystal_folder_pdb,pdb_file)
            print(f"Processing PDB file: {pdb_path}...")
            print(f"Processing crystal structure for pdb_id: {pdb_id}...")
            dockq_native = f'./{crystal_folder}/merged_crystals/{pdb_id}_merged.pdb'
            model_files = [f for f in os.listdir(model_folder_pdb) if f.startswith(pdb_id) and f.endswith(".pdb")]
            if len(model_files) == 5:
                print(f"Found 5 model files for {pdb_id}, processing each model...")
                for model_file in model_files:
                    model_number = model_file.split("_")[1].split(".")[0]
                    model_path = os.path.join(model_folder_pdb, model_file)
                    dockq_model = f'./{model_folder}/merged_models/{pdb_id}_{model_number}_merged.pdb'
                    print(f"  Processing model {model_number}...")
                    result_string, overall_rmsd, rmsd_TCRA_TCRB, rmsd_Peptide, rmsd_MHC_B2M, rmsd_CDR_TCRA, rmsd_CDR_TCRB = calculate_rmsd(
                        pdb_path, model_path, pdb_id, chain_dict, distance_cutoff=10.0)
                    dockq_score, irmsd, lrmsd, fnat, clashes = run_dockq(dockq_model, dockq_native)
                    row = {
                        "pdb_id": pdb_id,
                        "model_number": model_number,
                        "overall_rmsd": overall_rmsd,
                        "rmsd_TCRA_TCRB": rmsd_TCRA_TCRB,
                        "rmsd_Peptide": rmsd_Peptide,
                        "rmsd_MHC_B2M": rmsd_MHC_B2M,
                        "rmsd_CDR_TCRA": rmsd_CDR_TCRA,
                        "rmsd_CDR_TCRB": rmsd_CDR_TCRB,
                        "dockq_score": dockq_score,
                        "irmsd": irmsd,
                        "lrmsd": lrmsd,
                        "fnat": fnat,
                        "clashes": clashes}
                    dataframe = pd.concat([dataframe, pd.DataFrame([row])], ignore_index=True)
                    print(f"Processed: {pdb_id} model {model_number}")
                    print(result_string)
    return dataframe

# %%
df=process_pdbs("./structures/crystals/", "./structures/models/")
df.to_csv("./structures/crystal_vs_models.csv", index=False)
# Out:
# Processing PDB file: ./structures/crystals/cleaned_crystals_pdb/1lp9.pdb...
# Processing crystal structure for pdb_id: 1lp9...
# Found 5 model files for 1lp9, processing each model...
#   Processing model 2...
# Processed: 1lp9 model 2
# Number of CA in interface: 955, Overall iRMSD: 1.80 angstroms
# TCRA/TCRB: Number of CA: 198, iRMSD: 3.42 angstroms
# Peptide: Number of CA: 76, iRMSD: 0.92 angstroms
# MHC/B2M: Number of CA: 681, iRMSD: 1.02 angstroms
# CDR3 TCRA: 2.70 angstroms
# CDR3 TCRB: 3.40 angstroms
#
#   Processing model 3...
# Processed: 1lp9 model 3
# Number of CA in interface: 955, Overall iRMSD: 1.83 angstroms
# TCRA/TCRB: Number of CA: 198, iRMSD: 3.44 angstroms
# Peptide: Number of CA: 76, iRMSD: 0.99 angstroms
# MHC/B2M: Number of CA: 681, iRMSD: 1.07 angstroms
# CDR3 TCRA: 2.99 angstroms
# CDR3 TCRB: 3.49 angstroms
#
#   Processing model 1...
# Processed: 1lp9 model 1
# Number of CA in interface: 955, Overall iRMSD: 1.86 angstroms
# TCRA/TCRB: Number of CA: 198, iRMSD: 3.48 angstroms
# Peptide: Number of CA: 76, iRMSD: 1.00 angstroms
# MHC/B2M: Number of CA: 681, iRMSD: 1.09 angstroms
# CDR3 TCRA: 3.27 angstroms
# CDR3 TCRB: 3.29 angstroms
#
#   Processing model 0...
# Processed: 1lp9 model 0
# Number of CA in interface: 955, Overall iRMSD: 1.91 angstroms
# TCRA/TCRB: Number of CA: 198, iRMSD: 3.62 angstroms
# Peptide: Number of CA: 76, iRMSD: 1.02 angstroms
# MHC/B2M: Number of CA: 681, iRMSD: 1.11 angstroms
# CDR3 TCRA: 2.93 angstroms
# CDR3 TCRB: 3.47 angstroms
#
#   Processing model 4...
# Processed: 1lp9 model 4
# Number of CA in interface: 955, Overall iRMSD: 1.78 angstroms
# TCRA/TCRB: Number of CA: 198, iRMSD: 3.30 angstroms
# Peptide: Number of CA: 76, iRMSD: 0.92 angstroms
# MHC/B2M: Number of CA: 681, iRMSD: 1.09 angstroms
# CDR3 TCRA: 2.56 angstroms
# CDR3 TCRB: 3.33 angstroms
#
# Processing PDB file: ./structures/crystals/cleaned_crystals_pdb/1bd2.pdb...
# Processing crystal structure for pdb_id: 1bd2...
# Found 5 model files for 1bd2, processing each model...
#   Processing model 3...
# Processed: 1bd2 model 3
# Number of CA in interface: 994, Overall iRMSD: 1.08 angstroms
# TCRA/TCRB: Number of CA: 240, iRMSD: 1.79 angstroms
# Peptide: Number of CA: 77, iRMSD: 0.67 angstroms
# MHC/B2M: Number of CA: 677, iRMSD: 0.73 angstroms
# CDR3 TCRA: 0.92 angstroms
# CDR3 TCRB: 1.76 angstroms
#
#   Processing model 2...
# Processed: 1bd2 model 2
# Number of CA in interface: 994, Overall iRMSD: 1.18 angstroms
# TCRA/TCRB: Number of CA: 240, iRMSD: 1.96 angstroms
# Peptide: Number of CA: 77, iRMSD: 0.63 angstroms
# MHC/B2M: Number of CA: 677, iRMSD: 0.80 angstroms
# CDR3 TCRA: 1.08 angstroms
# CDR3 TCRB: 1.90 angstroms
#
#   Processing model 0...
# Processed: 1bd2 model 0
# Number of CA in interface: 994, Overall iRMSD: 1.09 angstroms
# TCRA/TCRB: Number of CA: 240, iRMSD: 1.79 angstroms
# Peptide: Number of CA: 77, iRMSD: 0.61 angstroms
# MHC/B2M: Number of CA: 677, iRMSD: 0.75 angstroms
# CDR3 TCRA: 0.97 angstroms
# CDR3 TCRB: 1.91 angstroms
#
#   Processing model 1...
# Processed: 1bd2 model 1
# Number of CA in interface: 994, Overall iRMSD: 1.21 angstroms
# TCRA/TCRB: Number of CA: 240, iRMSD: 2.03 angstroms
# Peptide: Number of CA: 77, iRMSD: 0.89 angstroms
# MHC/B2M: Number of CA: 677, iRMSD: 0.77 angstroms
# CDR3 TCRA: 1.11 angstroms
# CDR3 TCRB: 1.92 angstroms
#
#   Processing model 4...
# Processed: 1bd2 model 4
# Number of CA in interface: 994, Overall iRMSD: 1.28 angstroms
# TCRA/TCRB: Number of CA: 240, iRMSD: 2.15 angstroms
# Peptide: Number of CA: 77, iRMSD: 0.84 angstroms
# MHC/B2M: Number of CA: 677, iRMSD: 0.83 angstroms
# CDR3 TCRA: 1.27 angstroms
# CDR3 TCRB: 1.93 angstroms
#
# Processing PDB file: ./structures/crystals/cleaned_crystals_pdb/1ao7.pdb...
# Processing crystal structure for pdb_id: 1ao7...
# Found 5 model files for 1ao7, processing each model...
#   Processing model 4...
# Processed: 1ao7 model 4
# Number of CA in interface: 1020, Overall iRMSD: 1.14 angstroms
# TCRA/TCRB: Number of CA: 268, iRMSD: 1.82 angstroms
# Peptide: Number of CA: 77, iRMSD: 0.96 angstroms
# MHC/B2M: Number of CA: 675, iRMSD: 0.73 angstroms
# CDR3 TCRA: 0.75 angstroms
# CDR3 TCRB: 1.17 angstroms
#
#   Processing model 1...
# Processed: 1ao7 model 1
# Number of CA in interface: 1020, Overall iRMSD: 0.96 angstroms
# TCRA/TCRB: Number of CA: 268, iRMSD: 1.70 angstroms
# Peptide: Number of CA: 77, iRMSD: 0.67 angstroms
# MHC/B2M: Number of CA: 675, iRMSD: 0.45 angstroms
# CDR3 TCRA: 0.64 angstroms
# CDR3 TCRB: 1.22 angstroms
#
#   Processing model 0...
# Processed: 1ao7 model 0
# Number of CA in interface: 1020, Overall iRMSD: 1.15 angstroms
# TCRA/TCRB: Number of CA: 268, iRMSD: 1.83 angstroms
# Peptide: Number of CA: 77, iRMSD: 0.97 angstroms
# MHC/B2M: Number of CA: 675, iRMSD: 0.74 angstroms
# CDR3 TCRA: 0.67 angstroms
# CDR3 TCRB: 1.30 angstroms
#
#   Processing model 2...
# Processed: 1ao7 model 2
# Number of CA in interface: 1020, Overall iRMSD: 1.01 angstroms
# TCRA/TCRB: Number of CA: 268, iRMSD: 1.78 angstroms
# Peptide: Number of CA: 77, iRMSD: 0.77 angstroms
# MHC/B2M: Number of CA: 675, iRMSD: 0.47 angstroms
# CDR3 TCRA: 0.75 angstroms
# CDR3 TCRB: 1.25 angstroms
#
#   Processing model 3...
# Processed: 1ao7 model 3
# Number of CA in interface: 1020, Overall iRMSD: 1.15 angstroms
# TCRA/TCRB: Number of CA: 268, iRMSD: 1.83 angstroms
# Peptide: Number of CA: 77, iRMSD: 0.96 angstroms
# MHC/B2M: Number of CA: 675, iRMSD: 0.74 angstroms
# CDR3 TCRA: 0.77 angstroms
# CDR3 TCRB: 1.19 angstroms
#
# Processing PDB file: ./structures/crystals/cleaned_crystals_pdb/1oga.pdb...
# Processing crystal structure for pdb_id: 1oga...
# Found 5 model files for 1oga, processing each model...
#   Processing model 2...
# Processed: 1oga model 2
# Number of CA in interface: 926, Overall iRMSD: 0.56 angstroms
# TCRA/TCRB: Number of CA: 188, iRMSD: 0.80 angstroms
# Peptide: Number of CA: 69, iRMSD: 0.94 angstroms
# MHC/B2M: Number of CA: 669, iRMSD: 0.39 angstroms
# CDR3 TCRA: 0.98 angstroms
# CDR3 TCRB: 0.55 angstroms
#
#   Processing model 3...
# Processed: 1oga model 3
# Number of CA in interface: 926, Overall iRMSD: 0.57 angstroms
# TCRA/TCRB: Number of CA: 188, iRMSD: 0.83 angstroms
# Peptide: Number of CA: 69, iRMSD: 0.66 angstroms
# MHC/B2M: Number of CA: 669, iRMSD: 0.46 angstroms
# CDR3 TCRA: 0.92 angstroms
# CDR3 TCRB: 0.61 angstroms
#
#   Processing model 1...
# Processed: 1oga model 1
# Number of CA in interface: 926, Overall iRMSD: 0.57 angstroms
# TCRA/TCRB: Number of CA: 188, iRMSD: 0.82 angstroms
# Peptide: Number of CA: 69, iRMSD: 0.82 angstroms
# MHC/B2M: Number of CA: 669, iRMSD: 0.43 angstroms
# CDR3 TCRA: 0.98 angstroms
# CDR3 TCRB: 0.60 angstroms
#
#   Processing model 0...
# Processed: 1oga model 0
# Number of CA in interface: 926, Overall iRMSD: 0.53 angstroms
# TCRA/TCRB: Number of CA: 188, iRMSD: 0.76 angstroms
# Peptide: Number of CA: 69, iRMSD: 0.76 angstroms
# MHC/B2M: Number of CA: 669, iRMSD: 0.41 angstroms
# CDR3 TCRA: 0.93 angstroms
# CDR3 TCRB: 0.56 angstroms
#
#   Processing model 4...
# Processed: 1oga model 4
# Number of CA in interface: 926, Overall iRMSD: 0.59 angstroms
# TCRA/TCRB: Number of CA: 188, iRMSD: 0.85 angstroms
# Peptide: Number of CA: 69, iRMSD: 0.73 angstroms
# MHC/B2M: Number of CA: 669, iRMSD: 0.47 angstroms
# CDR3 TCRA: 0.99 angstroms
# CDR3 TCRB: 0.63 angstroms
#
# Processing PDB file: ./structures/crystals/cleaned_crystals_pdb/1fo0.pdb...
# Processing crystal structure for pdb_id: 1fo0...
# Found 5 model files for 1fo0, processing each model...
#   Processing model 0...
# Processed: 1fo0 model 0
# Number of CA in interface: 899, Overall iRMSD: 1.04 angstroms
# TCRA/TCRB: Number of CA: 145, iRMSD: 2.22 angstroms
# Peptide: Number of CA: 70, iRMSD: 0.64 angstroms
# MHC/B2M: Number of CA: 684, iRMSD: 0.57 angstroms
# CDR3 TCRA: 6.00 angstroms
# CDR3 TCRB: 1.42 angstroms
#
#   Processing model 1...
# Processed: 1fo0 model 1
# Number of CA in interface: 899, Overall iRMSD: 0.87 angstroms
# TCRA/TCRB: Number of CA: 145, iRMSD: 1.71 angstroms
# Peptide: Number of CA: 70, iRMSD: 0.65 angstroms
# MHC/B2M: Number of CA: 684, iRMSD: 0.58 angstroms
# CDR3 TCRA: 4.29 angstroms
# CDR3 TCRB: 0.86 angstroms
#
#   Processing model 3...
# Processed: 1fo0 model 3
# Number of CA in interface: 899, Overall iRMSD: 0.99 angstroms
# TCRA/TCRB: Number of CA: 145, iRMSD: 2.05 angstroms
# Peptide: Number of CA: 70, iRMSD: 0.75 angstroms
# MHC/B2M: Number of CA: 684, iRMSD: 0.58 angstroms
# CDR3 TCRA: 5.74 angstroms
# CDR3 TCRB: 0.83 angstroms
#
#   Processing model 2...
# Processed: 1fo0 model 2
# Number of CA in interface: 899, Overall iRMSD: 0.89 angstroms
# TCRA/TCRB: Number of CA: 145, iRMSD: 1.81 angstroms
# Peptide: Number of CA: 70, iRMSD: 0.74 angstroms
# MHC/B2M: Number of CA: 684, iRMSD: 0.54 angstroms
# CDR3 TCRA: 4.91 angstroms
# CDR3 TCRB: 0.78 angstroms
#
#   Processing model 4...
# Processed: 1fo0 model 4
# Number of CA in interface: 899, Overall iRMSD: 0.93 angstroms
# TCRA/TCRB: Number of CA: 145, iRMSD: 1.91 angstroms
# Peptide: Number of CA: 70, iRMSD: 0.63 angstroms
# MHC/B2M: Number of CA: 684, iRMSD: 0.57 angstroms
# CDR3 TCRA: 5.07 angstroms
# CDR3 TCRB: 1.19 angstroms
#
# Processing PDB file: ./structures/crystals/cleaned_crystals_pdb/1kj2.pdb...
# Processing crystal structure for pdb_id: 1kj2...
# Found 5 model files for 1kj2, processing each model...
#   Processing model 4...
# Processed: 1kj2 model 4
# Number of CA in interface: 976, Overall iRMSD: 0.80 angstroms
# TCRA/TCRB: Number of CA: 203, iRMSD: 1.42 angstroms
# Peptide: Number of CA: 67, iRMSD: 0.45 angstroms
# MHC/B2M: Number of CA: 706, iRMSD: 0.53 angstroms
# CDR3 TCRA: 1.49 angstroms
# CDR3 TCRB: 1.43 angstroms
#
#   Processing model 3...
# Processed: 1kj2 model 3
# Number of CA in interface: 976, Overall iRMSD: 0.85 angstroms
# TCRA/TCRB: Number of CA: 203, iRMSD: 1.48 angstroms
# Peptide: Number of CA: 67, iRMSD: 0.45 angstroms
# MHC/B2M: Number of CA: 706, iRMSD: 0.58 angstroms
# CDR3 TCRA: 1.50 angstroms
# CDR3 TCRB: 1.75 angstroms
#
#   Processing model 2...
# Processed: 1kj2 model 2
# Number of CA in interface: 976, Overall iRMSD: 0.72 angstroms
# TCRA/TCRB: Number of CA: 203, iRMSD: 1.20 angstroms
# Peptide: Number of CA: 67, iRMSD: 0.44 angstroms
# MHC/B2M: Number of CA: 706, iRMSD: 0.53 angstroms
# CDR3 TCRA: 1.35 angstroms
# CDR3 TCRB: 1.20 angstroms
#
#   Processing model 0...
# Processed: 1kj2 model 0
# Number of CA in interface: 976, Overall iRMSD: 0.95 angstroms
# TCRA/TCRB: Number of CA: 203, iRMSD: 1.83 angstroms
# Peptide: Number of CA: 67, iRMSD: 0.47 angstroms
# MHC/B2M: Number of CA: 706, iRMSD: 0.51 angstroms
# CDR3 TCRA: 1.38 angstroms
# CDR3 TCRB: 1.82 angstroms
#
#   Processing model 1...
# Processed: 1kj2 model 1
# Number of CA in interface: 976, Overall iRMSD: 0.78 angstroms
# TCRA/TCRB: Number of CA: 203, iRMSD: 1.40 angstroms
# Peptide: Number of CA: 67, iRMSD: 0.44 angstroms
# MHC/B2M: Number of CA: 706, iRMSD: 0.51 angstroms
# CDR3 TCRA: 1.31 angstroms
# CDR3 TCRB: 1.76 angstroms
#
# Processing PDB file: ./structures/crystals/cleaned_crystals_pdb/1mi5.pdb...
# Processing crystal structure for pdb_id: 1mi5...
# Found 5 model files for 1mi5, processing each model...
#   Processing model 0...
# Processed: 1mi5 model 0
# Number of CA in interface: 1009, Overall iRMSD: 1.21 angstroms
# TCRA/TCRB: Number of CA: 200, iRMSD: 1.94 angstroms
# Peptide: Number of CA: 75, iRMSD: 1.12 angstroms
# MHC/B2M: Number of CA: 734, iRMSD: 0.93 angstroms
# CDR3 TCRA: 1.85 angstroms
# CDR3 TCRB: 1.18 angstroms
#
#   Processing model 1...
# Processed: 1mi5 model 1
# Number of CA in interface: 1009, Overall iRMSD: 1.33 angstroms
# TCRA/TCRB: Number of CA: 200, iRMSD: 2.42 angstroms
# Peptide: Number of CA: 75, iRMSD: 1.13 angstroms
# MHC/B2M: Number of CA: 734, iRMSD: 0.83 angstroms
# CDR3 TCRA: 3.32 angstroms
# CDR3 TCRB: 1.20 angstroms
#
#   Processing model 3...
# Processed: 1mi5 model 3
# Number of CA in interface: 1009, Overall iRMSD: 1.38 angstroms
# TCRA/TCRB: Number of CA: 200, iRMSD: 2.53 angstroms
# Peptide: Number of CA: 75, iRMSD: 0.96 angstroms
# MHC/B2M: Number of CA: 734, iRMSD: 0.88 angstroms
# CDR3 TCRA: 3.53 angstroms
# CDR3 TCRB: 1.21 angstroms
#
#   Processing model 2...
# Processed: 1mi5 model 2
# Number of CA in interface: 1009, Overall iRMSD: 1.38 angstroms
# TCRA/TCRB: Number of CA: 200, iRMSD: 2.54 angstroms
# Peptide: Number of CA: 75, iRMSD: 0.99 angstroms
# MHC/B2M: Number of CA: 734, iRMSD: 0.87 angstroms
# CDR3 TCRA: 3.58 angstroms
# CDR3 TCRB: 1.38 angstroms
#
#   Processing model 4...
# Processed: 1mi5 model 4
# Number of CA in interface: 1009, Overall iRMSD: 1.38 angstroms
# TCRA/TCRB: Number of CA: 200, iRMSD: 2.60 angstroms
# Peptide: Number of CA: 75, iRMSD: 1.01 angstroms
# MHC/B2M: Number of CA: 734, iRMSD: 0.83 angstroms
# CDR3 TCRA: 3.59 angstroms
# CDR3 TCRB: 1.21 angstroms
#
# Processing PDB file: ./structures/crystals/cleaned_crystals_pdb/1nam.pdb...
# Processing crystal structure for pdb_id: 1nam...
# Found 5 model files for 1nam, processing each model...
#   Processing model 1...
# Processed: 1nam model 1
# Number of CA in interface: 911, Overall iRMSD: 1.43 angstroms
# TCRA/TCRB: Number of CA: 153, iRMSD: 3.08 angstroms
# Peptide: Number of CA: 68, iRMSD: 0.63 angstroms
# MHC/B2M: Number of CA: 690, iRMSD: 0.74 angstroms
# CDR3 TCRA: 5.93 angstroms
# CDR3 TCRB: 1.64 angstroms
#
#   Processing model 0...
# Processed: 1nam model 0
# Number of CA in interface: 911, Overall iRMSD: 1.28 angstroms
# TCRA/TCRB: Number of CA: 153, iRMSD: 2.76 angstroms
# Peptide: Number of CA: 68, iRMSD: 0.65 angstroms
# MHC/B2M: Number of CA: 690, iRMSD: 0.67 angstroms
# CDR3 TCRA: 5.13 angstroms
# CDR3 TCRB: 1.30 angstroms
#
#   Processing model 2...
# Processed: 1nam model 2
# Number of CA in interface: 911, Overall iRMSD: 1.05 angstroms
# TCRA/TCRB: Number of CA: 153, iRMSD: 1.92 angstroms
# Peptide: Number of CA: 68, iRMSD: 0.98 angstroms
# MHC/B2M: Number of CA: 690, iRMSD: 0.73 angstroms
# CDR3 TCRA: 3.41 angstroms
# CDR3 TCRB: 1.30 angstroms
#
#   Processing model 3...
# Processed: 1nam model 3
# Number of CA in interface: 911, Overall iRMSD: 1.13 angstroms
# TCRA/TCRB: Number of CA: 153, iRMSD: 2.05 angstroms
# Peptide: Number of CA: 68, iRMSD: 1.15 angstroms
# MHC/B2M: Number of CA: 690, iRMSD: 0.78 angstroms
# CDR3 TCRA: 3.42 angstroms
# CDR3 TCRB: 1.42 angstroms
#
#   Processing model 4...
# Processed: 1nam model 4
# Number of CA in interface: 911, Overall iRMSD: 1.18 angstroms
# TCRA/TCRB: Number of CA: 153, iRMSD: 2.26 angstroms
# Peptide: Number of CA: 68, iRMSD: 0.91 angstroms
# MHC/B2M: Number of CA: 690, iRMSD: 0.78 angstroms
# CDR3 TCRA: 4.10 angstroms
# CDR3 TCRB: 1.48 angstroms
#
# Processing PDB file: ./structures/crystals/cleaned_crystals_pdb/1mwa.pdb...
# Processing crystal structure for pdb_id: 1mwa...
# Found 5 model files for 1mwa, processing each model...
#   Processing model 2...
# Processed: 1mwa model 2
# Number of CA in interface: 1012, Overall iRMSD: 0.97 angstroms
# TCRA/TCRB: Number of CA: 265, iRMSD: 1.09 angstroms
# Peptide: Number of CA: 76, iRMSD: 1.15 angstroms
# MHC/B2M: Number of CA: 671, iRMSD: 0.89 angstroms
# CDR3 TCRA: 0.98 angstroms
# CDR3 TCRB: 0.89 angstroms
#
#   Processing model 3...
# Processed: 1mwa model 3
# Number of CA in interface: 1012, Overall iRMSD: 1.00 angstroms
# TCRA/TCRB: Number of CA: 265, iRMSD: 1.18 angstroms
# Peptide: Number of CA: 76, iRMSD: 1.14 angstroms
# MHC/B2M: Number of CA: 671, iRMSD: 0.89 angstroms
# CDR3 TCRA: 1.28 angstroms
# CDR3 TCRB: 0.77 angstroms
#
#   Processing model 1...
# Processed: 1mwa model 1
# Number of CA in interface: 1012, Overall iRMSD: 0.99 angstroms
# TCRA/TCRB: Number of CA: 265, iRMSD: 1.15 angstroms
# Peptide: Number of CA: 76, iRMSD: 1.15 angstroms
# MHC/B2M: Number of CA: 671, iRMSD: 0.90 angstroms
# CDR3 TCRA: 1.14 angstroms
# CDR3 TCRB: 0.89 angstroms
#
#   Processing model 0...
# Processed: 1mwa model 0
# Number of CA in interface: 1012, Overall iRMSD: 0.98 angstroms
# TCRA/TCRB: Number of CA: 265, iRMSD: 1.14 angstroms
# Peptide: Number of CA: 76, iRMSD: 1.18 angstroms
# MHC/B2M: Number of CA: 671, iRMSD: 0.89 angstroms
# CDR3 TCRA: 0.98 angstroms
# CDR3 TCRB: 0.76 angstroms
#
#   Processing model 4...
# Processed: 1mwa model 4
# Number of CA in interface: 1012, Overall iRMSD: 1.01 angstroms
# TCRA/TCRB: Number of CA: 265, iRMSD: 1.23 angstroms
# Peptide: Number of CA: 76, iRMSD: 1.15 angstroms
# MHC/B2M: Number of CA: 671, iRMSD: 0.89 angstroms
# CDR3 TCRA: 1.20 angstroms
# CDR3 TCRB: 0.78 angstroms
#
# Processing PDB file: ./structures/crystals/cleaned_crystals_pdb/1g6r.pdb...
# Processing crystal structure for pdb_id: 1g6r...
# Found 5 model files for 1g6r, processing each model...
#   Processing model 1...
# Processed: 1g6r model 1
# Number of CA in interface: 1004, Overall iRMSD: 1.18 angstroms
# TCRA/TCRB: Number of CA: 252, iRMSD: 1.51 angstroms
# Peptide: Number of CA: 74, iRMSD: 1.31 angstroms
# MHC/B2M: Number of CA: 678, iRMSD: 1.01 angstroms
# CDR3 TCRA: 1.82 angstroms
# CDR3 TCRB: 1.08 angstroms
#
#   Processing model 0...
# Processed: 1g6r model 0
# Number of CA in interface: 1004, Overall iRMSD: 1.18 angstroms
# TCRA/TCRB: Number of CA: 252, iRMSD: 1.54 angstroms
# Peptide: Number of CA: 74, iRMSD: 1.17 angstroms
# MHC/B2M: Number of CA: 678, iRMSD: 1.02 angstroms
# CDR3 TCRA: 1.75 angstroms
# CDR3 TCRB: 1.07 angstroms
#
#   Processing model 2...
# Processed: 1g6r model 2
# Number of CA in interface: 1004, Overall iRMSD: 1.16 angstroms
# TCRA/TCRB: Number of CA: 252, iRMSD: 1.45 angstroms
# Peptide: Number of CA: 74, iRMSD: 1.24 angstroms
# MHC/B2M: Number of CA: 678, iRMSD: 1.03 angstroms
# CDR3 TCRA: 1.64 angstroms
# CDR3 TCRB: 1.07 angstroms
#
#   Processing model 3...
# Processed: 1g6r model 3
# Number of CA in interface: 1004, Overall iRMSD: 1.34 angstroms
# TCRA/TCRB: Number of CA: 252, iRMSD: 1.72 angstroms
# Peptide: Number of CA: 74, iRMSD: 1.92 angstroms
# MHC/B2M: Number of CA: 678, iRMSD: 1.08 angstroms
# CDR3 TCRA: 1.98 angstroms
# CDR3 TCRB: 1.06 angstroms
#
#   Processing model 4...
# Processed: 1g6r model 4
# Number of CA in interface: 1004, Overall iRMSD: 1.17 angstroms
# TCRA/TCRB: Number of CA: 252, iRMSD: 1.46 angstroms
# Peptide: Number of CA: 74, iRMSD: 1.16 angstroms
# MHC/B2M: Number of CA: 678, iRMSD: 1.05 angstroms
# CDR3 TCRA: 1.52 angstroms
# CDR3 TCRB: 1.13 angstroms

# %% [markdown]
# # MODEL QUALITY METRICS

# %%
def calculate_global_plddt(json_file_path):
    """
    Calculate the mean of the values in the `atom_plddts` key from a JSON file.

    Args:
        json_file_path (str): Path to the JSON file.

    Returns:
        float: The mean of the values in `atom_plddts`, or None if the key is empty.
    """
    try:
        with open(json_file_path, 'r') as file:
            data = json.load(file)
        
        atom_plddts = data.get('atom_plddts', [])
        if not atom_plddts:
            print("No data found in 'atom_plddts'.")
            return None
        
        mean_plddt = sum(atom_plddts) / len(atom_plddts)
        return mean_plddt

    except FileNotFoundError:
        print(f"Error: The file {json_file_path} was not found.")
        return None
    except json.JSONDecodeError:
        print("Error: Failed to decode the JSON file. Please check its format.")
        return None
    
def extract_b_factors(cdr_atoms, chain):
    """
    Extract B-factors for a given list of atoms from a specific chain.
    
    Args:
        cdr_atoms: List of tuples containing (atom_name, residue_id, residue_name, chain_id).
        chain: Bio.PDB.Chain object corresponding to the chain to extract B-factors from.
        
    Returns:
        A list of B-factors for the specified atoms.
    """
    b_factors = []
    for atomname, resid, resname, chainid in cdr_atoms:
        if chainid == chain.id:
            try:
                residue = chain[resid]  # Access the residue using its ID
                if atomname in residue:  # Check if the atom exists in the residue
                    atom = residue[atomname]
                    b_factors.append(atom.get_bfactor())
                else:
                    print(f"Atom {atomname} not found in residue {resid} ({resname}) of chain {chain.id}")
            except KeyError:
                print(f"Residue {resid} ({resname}) not found in chain {chain.id}")
    return b_factors

def cdr_plddts(model_file, alpha_chain, beta_chain):
    model_sequences, model_dict = extract_sequences(model_file)
    residues_A = extract_residues_and_resids(model_file, alpha_chain)
    residues_B = extract_residues_and_resids(model_file, beta_chain)
    anarci_A = run_anarci(model_sequences[alpha_chain])
    anarci_B = run_anarci(model_sequences[beta_chain])
    parsed_A = parse_anarci_output(anarci_A)
    parsed_B = parse_anarci_output(anarci_B)
    map_A = map_imgt_to_original(parsed_A, residues_A)
    map_B = map_imgt_to_original(parsed_B, residues_B)

    # Parse CDR regions from the maps
    cdr3_A = parse_CDR3(map_A)
    cdr3_B = parse_CDR3(map_B)
    cdr2_A = parse_CDR2(map_A)
    cdr2_B = parse_CDR2(map_B)
    cdr1_A = parse_CDR1(map_A)
    cdr1_B = parse_CDR1(map_B)

    # Extract atom information for each CDR
    cdr3_atoms_A = extract_atoms_for_cdr(cdr3_A, model_file, alpha_chain)
    cdr3_atoms_B = extract_atoms_for_cdr(cdr3_B, model_file, beta_chain)
    cdr2_atoms_A = extract_atoms_for_cdr(cdr2_A, model_file, alpha_chain)
    cdr2_atoms_B = extract_atoms_for_cdr(cdr2_B, model_file, beta_chain)
    cdr1_atoms_A = extract_atoms_for_cdr(cdr1_A, model_file, alpha_chain)
    cdr1_atoms_B = extract_atoms_for_cdr(cdr1_B, model_file, beta_chain)

    
    # Parse the structure based on file type (PDB or MMCIF)
    if model_file.endswith(".pdb"):
        parser = PDB.PDBParser(QUIET=True)
    else:
        parser = PDB.MMCIFParser(QUIET=True)
        
    structure = parser.get_structure("Model", model_file)
    chain_A = structure[0][alpha_chain]
    chain_B = structure[0][beta_chain]
    
    # Extract B-factors for each CDR region separately
    b_factors_cdr1_A = extract_b_factors(cdr1_atoms_A, chain_A)
    b_factors_cdr2_A = extract_b_factors(cdr2_atoms_A, chain_A)
    b_factors_cdr3_A = extract_b_factors(cdr3_atoms_A, chain_A)
    
    b_factors_cdr1_B = extract_b_factors(cdr1_atoms_B, chain_B)
    b_factors_cdr2_B = extract_b_factors(cdr2_atoms_B, chain_B)
    b_factors_cdr3_B = extract_b_factors(cdr3_atoms_B, chain_B)

    # Mean 
    mean_cdr1_A = np.mean(b_factors_cdr1_A)
    mean_cdr2_A = np.mean(b_factors_cdr2_A)
    mean_cdr3_A = np.mean(b_factors_cdr3_A)
    mean_cdr1_B = np.mean(b_factors_cdr1_B)
    mean_cdr2_B = np.mean(b_factors_cdr2_B)
    mean_cdr3_B = np.mean(b_factors_cdr3_B)

    # Return the B-factors for each CDR region separately
    return mean_cdr1_A, mean_cdr2_A, mean_cdr3_A, mean_cdr1_B, mean_cdr2_B, mean_cdr3_B

def calculate_iptms(json_file_path, length=5):
    """
    Calculates the mean of `chain_iptm` and the mean of interface TCR-pMHC iPTMs
    using fixed chain mappings.

    Args:
        json_file_path (str): Path to the JSON file.

    Returns:
        dict: A dictionary with the calculated means.
    """
    try:
        # Load the JSON data from the file
        with open(json_file_path, 'r') as file:
            data = json.load(file)
        
        # Calculate the mean of chain_iptm
        chain_iptm = data.get('chain_iptm', [])
        if not chain_iptm:
            print("No data found in 'chain_iptm'.")
            chain_iptm_mean = None
        else:
            chain_iptm_mean = sum(chain_iptm) / len(chain_iptm)
        
        # Calculate the mean for interface TCR-pMHC
        chain_pair_iptm = data.get('chain_pair_iptm', [])
        if not chain_pair_iptm:
            print("No data found in 'chain_pair_iptm'.")
            tcr_pmch_mean = None
        else:
            # Fixed indices for TCR-pMHC interactions
            # A (MHC) = 0, B (B2M) = 1, C (peptide) = 2, D (TCRa) = 3, E (TCRb) = 4
            if length == 5:
                tcr_pmch_pairs = [
                    chain_pair_iptm[0][3],  # MHC-TCRa 
                    chain_pair_iptm[0][4],  # MHC-TCRb 
                    chain_pair_iptm[2][3],  # pep-TCRa
                    chain_pair_iptm[2][4]]  # pep-TCRb 
                tcr_pmch_iptm = sum(tcr_pmch_pairs) / len(tcr_pmch_pairs)
            elif length == 4:
                # A (MHC) = 0, C (peptide) = 1, D (TCRa) = 2, E (TCRb) = 3
                tcr_pmch_pairs = [
                    chain_pair_iptm[0][2],  # MHC-TCRa 
                    chain_pair_iptm[0][3],  # MHC-TCRb 
                    chain_pair_iptm[1][2],  # pep-TCRa
                    chain_pair_iptm[1][3]]  # pep-TCRb 
                tcr_pmch_iptm = sum(tcr_pmch_pairs) / len(tcr_pmch_pairs)
        return chain_iptm_mean, tcr_pmch_iptm
    
    except FileNotFoundError:
        print(f"File not found: {json_file_path}")
        return None
    except KeyError as e:
        print(f"Missing key in JSON data: {e}")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None
    
import json

def calculate_pdockq (model_file):
    command=f"python ./scripts_py/pdockq.py --pdbfile {model_file}"
    result = subprocess.run(command, shell=True, capture_output=True, text=True, check=True)
    # Output is displayed as pDockQ = 0.609 for ./pre/merged_models_AB/1ao7_0_merged.pdb This corresponds to a PPV of at least 0.9400192
    # Capture pDockq
    pdockq = float(result.stdout.split('=')[1].split(' ')[1])
    return result.stdout, pdockq

def calculate_pdockq2_json (model_file, json_file):
    command=f"python ./scripts_py/pdockq2_json.py -json {json_file} -pdb {model_file}"
    result=subprocess.run(command, shell=True, capture_output=True, text=True, check=True)
    ipae_A = float(result.stdout.split('\n')[1].split(' ')[1])
    ipae_B = float(result.stdout.split('\n')[2].split(' ')[1])
    pdockq2_A= float(result.stdout.split('\n')[4].split(' ')[1])
    pdockq2_B= float(result.stdout.split('\n')[5].split(' ')[1])
    return result.stdout, ipae_A, ipae_B, pdockq2_A, pdockq2_B

# %%
all_data='./af3_output/1ao7/1ao7_full_data_0.json'
summary_conf= './models/1ao7/1ao7_summary_confidences_0.json'
model_pdb='./af3_output/cleaned_models_pdb/1ao7_model_0.pdb'
model_merged='./af3_output/merged_models_AB/1ao7_0_merged.pdb'

mean= calculate_global_plddt(all_data)
b_factors_cdr1_A, b_factors_cdr2_A, b_factors_cdr3_A, b_factors_cdr1_B, b_factors_cdr2_B, b_factors_cdr3_B = cdr_plddts(model_pdb, "D", "E")
iptm_mean, iptm_tcrpmhc = calculate_iptms(summary_conf)
stdout, pdockq = calculate_pdockq(model_merged)
stdout2, pdockq2_A, pdockq2_B = calculate_pdockq2_json(model_merged, all_data)

# Print the results
print("Global pLDDT:", mean)
print("\nCDR pLDDTs:")
print("CDR1 A:", b_factors_cdr1_A, "CDR1 B:", b_factors_cdr1_B)
print("CDR2 A:", b_factors_cdr2_A, "CDR2 B:", b_factors_cdr2_B)
print("CDR3 A:", b_factors_cdr3_A, "CDR3 B:", b_factors_cdr3_B)

print("\nipTM complex: ", iptm_mean, "TCR-pMHC ipTM", iptm_tcrpmhc)

print("\nPDockQ: ", pdockq)
print("\nPDockQ2: ", pdockq2_A, pdockq2_B)
# Out:
# Error: The file ./af3_output/1ao7/1ao7_full_data_0.json was not found.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 7
#       4 model_merged='./af3_output/merged_models_AB/1ao7_0_merged.pdb'
#       6 mean= calculate_global_plddt(all_data)
# ----> 7 b_factors_cdr1_A, b_factors_cdr2_A, b_factors_cdr3_A, b_factors_cdr1_B, b_factors_cdr2_B, b_factors_cdr3_B = cdr_plddts(model_pdb, "D", "E")
#       8 iptm_mean, iptm_tcrpmhc = calculate_iptms(summary_conf)
#       9 stdout, pdockq = calculate_pdockq(model_merged)
#
# Cell In[4], line 56, in cdr_plddts(model_file, alpha_chain, beta_chain)
#      55 def cdr_plddts(model_file, alpha_chain, beta_chain):
# ---> 56     model_sequences, model_dict = extract_sequences(model_file)
#      57     residues_A = extract_residues_and_resids(model_file, alpha_chain)
#      58     residues_B = extract_residues_and_resids(model_file, beta_chain)
#
# Cell In[6], line 131, in extract_sequences(pdb_file)
#     129 if pdb_file.endswith(".pdb"):
#     130     parser = PDB.PDBParser(QUIET=True)
# --> 131     structure = parser.get_structure('structure', pdb_file)
#     132 else:
#     133     parser=PDB.MMCIFParser(QUIET=True)
#
# File /opt/miniconda3/envs/anarci/lib/python3.12/site-packages/Bio/PDB/PDBParser.py:96, in PDBParser.get_structure(self, id, file)
#      93 # Make a StructureBuilder instance (pass id of structure as parameter)
#      94 self.structure_builder.init_structure(id)
# ---> 96 with as_handle(file) as handle:
#      97     lines = handle.readlines()
#      98     if not lines:
#
# File /opt/miniconda3/envs/anarci/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /opt/miniconda3/envs/anarci/lib/python3.12/site-packages/Bio/File.py:72, in as_handle(handleish, mode, **kwargs)
#      30 r"""Context manager to ensure we are using a handle.
#      31
#      32 Context manager for arguments that can be passed to SeqIO and AlignIO read, write,
#    (...)
#      69
#      70 """
#      71 try:
# ---> 72     with open(handleish, mode, **kwargs) as fp:
#      73         yield fp
#      74 except TypeError:
#
# FileNotFoundError: [Errno 2] No such file or directory: './af3_output/cleaned_models_pdb/1ao7_model_0.pdb'

# %%
for folder in os.listdir("./af_predictions_all/af3_output"):
    dataframe = pd.DataFrame()
    if len(folder) == 4:
        pdb_id = folder
        for folder2 in os.listdir(f"./af_predictions_all/af3_output/{folder}"):
            if folder2.startswith("seed-"):
                model_number = folder2.split("-")[-1]
                model_path = f"./af_predictions_all/models/cleaned_models/{pdb_id}_{model_number}.pdb"
                seqs, _ = extract_sequences(model_path)
                length = len(seqs)
                print(length)
                merged_model_AB=f"./af_predictions_all/models/merged_models_AB/{pdb_id}_{model_number}_merged.pdb"
                merged_model_BA=f"./af_predictions_all/models/merged_models_BA/{pdb_id}_{model_number}_merged.pdb"
                pdb_model=f"./af_predictions_all/models/cleaned_models/{pdb_id}_{model_number}.pdb"
                folder2_path=f"./af_predictions_all/af3_output/{folder}/{folder2}"
                print(f"Processing model {model_number} for pdb_id: {pdb_id}...")
                for file in os.listdir(folder2_path):
                    if file.endswith(".cif"):
                        cif_file = os.path.join(folder2_path, file)
                    if file.endswith(".json") and file.startswith("summary"):
                        summary_json = os.path.join(folder2_path, file)
                    if file.endswith(".json") and not file.startswith("summary"):
                        all_data_json = os.path.join(folder2_path, file)

                        mean = calculate_global_plddt(all_data_json)
                        
                        if length == 5:
                            b_factors_cdr1_A, b_factors_cdr2_A, b_factors_cdr3_A, b_factors_cdr1_B, b_factors_cdr2_B, b_factors_cdr3_B = cdr_plddts(pdb_model, "D", "E")
                            iptm_mean, iptm_tcrpmhc = calculate_iptms(summary_json)
                            
                        if length == 4:
                            b_factors_cdr1_A, b_factors_cdr2_A, b_factors_cdr3_A, b_factors_cdr1_B, b_factors_cdr2_B, b_factors_cdr3_B = cdr_plddts(pdb_model, "C", "D")
                            iptm_mean, iptm_tcrpmhc = calculate_iptms(summary_json, length=4)
                        _, pdockq_AB = calculate_pdockq(merged_model_AB)
                        _, pdockq_BA = calculate_pdockq(merged_model_BA)
                        _, avgipae_A, avgipae_B, pdockq2_A, pdockq2_B = calculate_pdockq2_json(merged_model_AB, all_data_json)
                        _, avgipae_A2, avgipae_B2, pdockq2_A2, pdockq2_B2 = calculate_pdockq2_json(merged_model_BA, all_data_json)
                        row = {
                                "pdb_id": pdb_id,
                                "model_number": model_number,
                                "global_plddt": mean,
                                "cdr1_A": b_factors_cdr1_A,
                                "cdr2_A": b_factors_cdr2_A,
                                "cdr3_A": b_factors_cdr3_A,
                                "cdr1_B": b_factors_cdr1_B,
                                "cdr2_B": b_factors_cdr2_B,
                                "cdr3_B": b_factors_cdr3_B,
                                "iptm_mean": iptm_mean,
                                "iptm_tcrpmhc": iptm_tcrpmhc,
                                "pdockq_AB": pdockq_AB,
                                "pdockq_BA": pdockq_BA,
                                "avgipae_A_AB": avgipae_A,
                                "avgipae_B_AB": avgipae_B,
                                "pdockq2_A_AB": pdockq2_A,
                                "pdockq2_A_BA": pdockq2_B,
                                "avgipae_A_BA": avgipae_A2,
                                "avgipae_B_BA": avgipae_B2,
                                "pdockq2_A_BA": pdockq2_A2,
                                "pdockq2_B_BA": pdockq2_B2}
                        print(row)
                        dataframe = pd.concat([dataframe, pd.DataFrame([row])], ignore_index=True)
df.to_csv("./af3_predictions_all/model.csv", index=False)

# %%
import os
import pandas as pd

# Path to the CSV file
csv_path = "./af3_predictions_all/model.csv"

# Ensure that the directory exists, if not, create it
csv_dir = os.path.dirname(csv_path)
if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)

# Initialize or read the existing CSV file
if os.path.exists(csv_path) and os.stat(csv_path).st_size > 0:
    df_existing = pd.read_csv(csv_path)
    # Ensure that the CSV has the necessary columns
    if 'pdb_id' in df_existing.columns and 'model_number' in df_existing.columns:
        # Create a set of existing "pdb_id_model_number" to avoid reprocessing
        existing_combinations = set(zip(df_existing['pdb_id'], df_existing['model_number']))
    else:
        # If the necessary columns are missing, initialize an empty set
        existing_combinations = set()
else:
    # If the CSV doesn't exist or is empty, initialize an empty set
    df_existing = pd.DataFrame()
    existing_combinations = set()

# Iterate through the folders and files
for folder in os.listdir("./af_predictions_all/af3_output"):
    if len(folder) == 4:  # Assuming pdb_id length is 4
        pdb_id = folder
        for folder2 in os.listdir(f"./af_predictions_all/af3_output/{folder}"):
            if folder2.startswith("seed-"):
                model_number = folder2.split("-")[-1]
                # Skip this model if it's already in the CSV
                if (pdb_id, model_number) in existing_combinations:
                    print(f"Skipping {pdb_id}_{model_number} as it has already been processed.")
                    continue
                
                model_path = f"./af_predictions_all/models/cleaned_models/{pdb_id}_{model_number}.pdb"
                seqs, _ = extract_sequences(model_path)
                length = len(seqs)
                print(f"Processing model {model_number} for pdb_id: {pdb_id}...")
                
                # Construct paths
                merged_model_AB = f"./af_predictions_all/models/merged_models_AB/{pdb_id}_{model_number}_merged.pdb"
                merged_model_BA = f"./af_predictions_all/models/merged_models_BA/{pdb_id}_{model_number}_merged.pdb"
                pdb_model = f"./af_predictions_all/models/cleaned_models/{pdb_id}_{model_number}.pdb"
                folder2_path = f"./af_predictions_all/af3_output/{folder}/{folder2}"
                
                for file in os.listdir(folder2_path):
                    if file.endswith(".cif"):
                        cif_file = os.path.join(folder2_path, file)
                    if file.endswith(".json") and file.startswith("summary"):
                        summary_json = os.path.join(folder2_path, file)
                    if file.endswith(".json") and not file.startswith("summary"):
                        all_data_json = os.path.join(folder2_path, file)

                        # Calculate global pLDDT and iptm
                        mean = calculate_global_plddt(all_data_json)
                        
                        if length == 5:
                            b_factors_cdr1_A, b_factors_cdr2_A, b_factors_cdr3_A, b_factors_cdr1_B, b_factors_cdr2_B, b_factors_cdr3_B = cdr_plddts(pdb_model, "D", "E")
                            iptm_mean, iptm_tcrpmhc = calculate_iptms(summary_json)
                            
                        if length == 4:
                            b_factors_cdr1_A, b_factors_cdr2_A, b_factors_cdr3_A, b_factors_cdr1_B, b_factors_cdr2_B, b_factors_cdr3_B = cdr_plddts(pdb_model, "C", "D")
                            iptm_mean, iptm_tcrpmhc = calculate_iptms(summary_json, length=4)
                        
                        # Calculate docking parameters
                        _, pdockq_AB = calculate_pdockq(merged_model_AB)
                        _, pdockq_BA = calculate_pdockq(merged_model_BA)
                        _, avgipae_A, avgipae_B, pdockq2_A, pdockq2_B = calculate_pdockq2_json(merged_model_AB, all_data_json)
                        _, avgipae_A2, avgipae_B2, pdockq2_A2, pdockq2_B2 = calculate_pdockq2_json(merged_model_BA, all_data_json)
                        
                        # Create row data
                        row = {
                            "pdb_id": pdb_id,
                            "model_number": model_number,
                            "global_plddt": mean,
                            "cdr1_A": b_factors_cdr1_A,
                            "cdr2_A": b_factors_cdr2_A,
                            "cdr3_A": b_factors_cdr3_A,
                            "cdr1_B": b_factors_cdr1_B,
                            "cdr2_B": b_factors_cdr2_B,
                            "cdr3_B": b_factors_cdr3_B,
                            "iptm_mean": iptm_mean,
                            "iptm_tcrpmhc": iptm_tcrpmhc,
                            "pdockq_AB": pdockq_AB,
                            "pdockq_BA": pdockq_BA,
                            "avgipae_A_AB": avgipae_A,
                            "avgipae_B_AB": avgipae_B,
                            "pdockq2_A_AB": pdockq2_A,
                            "pdockq2_A_BA": pdockq2_B,
                            "avgipae_A_BA": avgipae_A2,
                            "avgipae_B_BA": avgipae_B2,
                            "pdockq2_A_BA": pdockq2_A2,
                            "pdockq2_B_BA": pdockq2_B2
                        }
                        print(row)
                        
                        # Save the row to the CSV immediately
                        row_df = pd.DataFrame([row])
                        row_df.to_csv(csv_path, mode='a', header=not os.path.exists(csv_path), index=False)

                # Add the current combination to the set of processed models
                existing_combinations.add((pdb_id, model_number))
# Out:
# Processing model 0 for pdb_id: 5wlg...
# {'pdb_id': '5wlg', 'model_number': '0', 'global_plddt': 89.97140990159902, 'cdr1_A': 83.16725, 'cdr2_A': 84.91209677419354, 'cdr3_A': 74.1575, 'cdr1_B': 86.90913043478261, 'cdr2_B': 86.6615909090909, 'cdr3_B': 81.1245054945055, 'iptm_mean': 0.792, 'iptm_tcrpmhc': 0.8, 'pdockq_AB': 0.401, 'pdockq_BA': 0.401, 'avgipae_A_AB': 0.3894232748161533, 'avgipae_B_AB': 0.4695454977934307, 'pdockq2_A_AB': 0.028794491384602106, 'pdockq2_A_BA': 0.669402399363523, 'avgipae_A_BA': 0.9221867984918537, 'avgipae_B_BA': 0.8459526847966568, 'pdockq2_B_BA': 0.29726644727714774}
# Processing model 1 for pdb_id: 5wlg...
# {'pdb_id': '5wlg', 'model_number': '1', 'global_plddt': 90.02234009840099, 'cdr1_A': 82.97375, 'cdr2_A': 85.01, 'cdr3_A': 73.95906249999999, 'cdr1_B': 86.555, 'cdr2_B': 86.10545454545455, 'cdr3_B': 80.59483516483516, 'iptm_mean': 0.796, 'iptm_tcrpmhc': 0.8025, 'pdockq_AB': 0.393, 'pdockq_BA': 0.393, 'avgipae_A_AB': 0.37492175745994655, 'avgipae_B_AB': 0.470143838835718, 'pdockq2_A_AB': 0.026430392209697347, 'pdockq2_A_BA': 0.6576953078617477, 'avgipae_A_BA': 0.9178523077464993, 'avgipae_B_BA': 0.8336238005166037, 'pdockq2_B_BA': 0.2714993689319676}
# Processing model 4 for pdb_id: 5wlg...
# {'pdb_id': '5wlg', 'model_number': '4', 'global_plddt': 89.86012607626077, 'cdr1_A': 82.30025, 'cdr2_A': 84.65709677419358, 'cdr3_A': 71.68828124999999, 'cdr1_B': 86.24086956521741, 'cdr2_B': 85.87931818181818, 'cdr3_B': 80.94109890109891, 'iptm_mean': 0.792, 'iptm_tcrpmhc': 0.795, 'pdockq_AB': 0.331, 'pdockq_BA': 0.331, 'avgipae_A_AB': 0.3839784978466311, 'avgipae_B_AB': 0.4526804867954751, 'pdockq2_A_AB': 0.027487089767034237, 'pdockq2_A_BA': 0.6398662244020559, 'avgipae_A_BA': 0.9156109687436746, 'avgipae_B_BA': 0.8335027436577441, 'pdockq2_B_BA': 0.2690718894171758}
# Processing model 3 for pdb_id: 5wlg...
# {'pdb_id': '5wlg', 'model_number': '3', 'global_plddt': 89.9107426199262, 'cdr1_A': 82.59525, 'cdr2_A': 84.69806451612904, 'cdr3_A': 72.63250000000001, 'cdr1_B': 86.50608695652174, 'cdr2_B': 86.32545454545455, 'cdr3_B': 80.5389010989011, 'iptm_mean': 0.792, 'iptm_tcrpmhc': 0.8, 'pdockq_AB': 0.416, 'pdockq_BA': 0.416, 'avgipae_A_AB': 0.41291187309836, 'avgipae_B_AB': 0.48147102969429306, 'pdockq2_A_AB': 0.03228160713373265, 'pdockq2_A_BA': 0.6663477933808732, 'avgipae_A_BA': 0.9228491225877646, 'avgipae_B_BA': 0.8385444916267117, 'pdockq2_B_BA': 0.2865861972066936}
# Processing model 2 for pdb_id: 5wlg...
# {'pdb_id': '5wlg', 'model_number': '2', 'global_plddt': 89.94499538745387, 'cdr1_A': 82.23125, 'cdr2_A': 84.52580645161291, 'cdr3_A': 72.7159375, 'cdr1_B': 86.60021739130435, 'cdr2_B': 85.96, 'cdr3_B': 81.10164835164834, 'iptm_mean': 0.792, 'iptm_tcrpmhc': 0.7925, 'pdockq_AB': 0.383, 'pdockq_BA': 0.383, 'avgipae_A_AB': 0.37102933911383307, 'avgipae_B_AB': 0.46536492560518267, 'pdockq2_A_AB': 0.026060818316172137, 'pdockq2_A_BA': 0.6526263871696274, 'avgipae_A_BA': 0.9162729492410273, 'avgipae_B_BA': 0.8340737408064741, 'pdockq2_B_BA': 0.27470116203555595}
# Processing model 2 for pdb_id: 4mji...
# {'pdb_id': '4mji', 'model_number': '2', 'global_plddt': 92.0856339969372, 'cdr1_A': 92.78567567567568, 'cdr2_A': 91.64677419354841, 'cdr3_A': 92.7798780487805, 'cdr1_B': 94.6121875, 'cdr2_B': 94.19624999999999, 'cdr3_B': 94.64847222222222, 'iptm_mean': 0.86, 'iptm_tcrpmhc': 0.87, 'pdockq_AB': 0.618, 'pdockq_BA': 0.618, 'avgipae_A_AB': 0.5892325737192136, 'avgipae_B_AB': 0.507641994147091, 'pdockq2_A_AB': 0.14055831371504388, 'pdockq2_A_BA': 0.8815233067407809, 'avgipae_A_BA': 0.9747723195528761, 'avgipae_B_BA': 0.9622881381188061, 'pdockq2_B_BA': 0.8148915121427158}
# Processing model 4 for pdb_id: 4mji...
# {'pdb_id': '4mji', 'model_number': '4', 'global_plddt': 91.87821898928024, 'cdr1_A': 92.35567567567568, 'cdr2_A': 91.26854838709679, 'cdr3_A': 92.06304878048782, 'cdr1_B': 94.5065625, 'cdr2_B': 93.825, 'cdr3_B': 94.45902777777779, 'iptm_mean': 0.858, 'iptm_tcrpmhc': 0.87, 'pdockq_AB': 0.62, 'pdockq_BA': 0.62, 'avgipae_A_AB': 0.5931286412423757, 'avgipae_B_AB': 0.5284963468409097, 'pdockq2_A_AB': 0.14245055234057405, 'pdockq2_A_BA': 0.879525546702035, 'avgipae_A_BA': 0.9748121994230204, 'avgipae_B_BA': 0.963517875701642, 'pdockq2_B_BA': 0.811497567186111}
# Processing model 3 for pdb_id: 4mji...
# {'pdb_id': '4mji', 'model_number': '3', 'global_plddt': 92.09213323124042, 'cdr1_A': 92.82756756756756, 'cdr2_A': 91.69241935483873, 'cdr3_A': 92.63573170731709, 'cdr1_B': 94.3353125, 'cdr2_B': 93.17075, 'cdr3_B': 94.70055555555555, 'iptm_mean': 0.86, 'iptm_tcrpmhc': 0.87, 'pdockq_AB': 0.62, 'pdockq_BA': 0.62, 'avgipae_A_AB': 0.5960313880358661, 'avgipae_B_AB': 0.527279774825338, 'pdockq2_A_AB': 0.14455189332857835, 'pdockq2_A_BA': 0.8752082486644374, 'avgipae_A_BA': 0.9733635791284186, 'avgipae_B_BA': 0.9619165371533529, 'pdockq2_B_BA': 0.8062191391559571}
# Processing model 1 for pdb_id: 4mji...
# {'pdb_id': '4mji', 'model_number': '1', 'global_plddt': 92.19656049004595, 'cdr1_A': 92.89432432432434, 'cdr2_A': 91.71467741935484, 'cdr3_A': 92.78768292682926, 'cdr1_B': 94.71437499999999, 'cdr2_B': 94.20225, 'cdr3_B': 94.77166666666666, 'iptm_mean': 0.866, 'iptm_tcrpmhc': 0.8775, 'pdockq_AB': 0.623, 'pdockq_BA': 0.623, 'avgipae_A_AB': 0.6114354438380781, 'avgipae_B_AB': 0.5298422575089294, 'pdockq2_A_AB': 0.16140776944949856, 'pdockq2_A_BA': 0.8848007490028954, 'avgipae_A_BA': 0.9761474559016743, 'avgipae_B_BA': 0.9639485721425639, 'pdockq2_B_BA': 0.8203748527323205}
# Processing model 0 for pdb_id: 4mji...
# {'pdb_id': '4mji', 'model_number': '0', 'global_plddt': 92.01670137825423, 'cdr1_A': 92.82270270270268, 'cdr2_A': 91.6122580645161, 'cdr3_A': 92.84768292682926, 'cdr1_B': 94.59187499999999, 'cdr2_B': 94.1935, 'cdr3_B': 94.51888888888888, 'iptm_mean': 0.86, 'iptm_tcrpmhc': 0.87, 'pdockq_AB': 0.628, 'pdockq_BA': 0.628, 'avgipae_A_AB': 0.5837123087932637, 'avgipae_B_AB': 0.5006811895313115, 'pdockq2_A_AB': 0.13613740524439413, 'pdockq2_A_BA': 0.8828998973358821, 'avgipae_A_BA': 0.9747960786717943, 'avgipae_B_BA': 0.9638157757597364, 'pdockq2_B_BA': 0.8193331839175274}
# Processing model 0 for pdb_id: 6r2l...
# {'pdb_id': '6r2l', 'model_number': '0', 'global_plddt': 93.3572456799399, 'cdr1_A': 92.05081081081082, 'cdr2_A': 95.86179487179486, 'cdr3_A': 85.92714285714287, 'cdr1_B': 92.49731707317073, 'cdr2_B': 83.69136363636363, 'cdr3_B': 94.98468085106384, 'iptm_mean': 0.8619999999999999, 'iptm_tcrpmhc': 0.875, 'pdockq_AB': 0.648, 'pdockq_BA': 0.648, 'avgipae_A_AB': 0.6498534597223442, 'avgipae_B_AB': 0.5828326149064065, 'pdockq2_A_AB': 0.1985960289372055, 'pdockq2_A_BA': 0.904659276177414, 'avgipae_A_BA': 0.9743179426504959, 'avgipae_B_BA': 0.9543738874710593, 'pdockq2_B_BA': 0.7872664825194039}
# Processing model 1 for pdb_id: 6r2l...
# {'pdb_id': '6r2l', 'model_number': '1', 'global_plddt': 93.16643726521413, 'cdr1_A': 91.29972972972975, 'cdr2_A': 95.60923076923079, 'cdr3_A': 87.64928571428572, 'cdr1_B': 92.30951219512195, 'cdr2_B': 83.30409090909092, 'cdr3_B': 95.18021276595748, 'iptm_mean': 0.858, 'iptm_tcrpmhc': 0.875, 'pdockq_AB': 0.64, 'pdockq_BA': 0.64, 'avgipae_A_AB': 0.6446799980440677, 'avgipae_B_AB': 0.5730310164976103, 'pdockq2_A_AB': 0.19923666239763027, 'pdockq2_A_BA': 0.9158117910981017, 'avgipae_A_BA': 0.9777257631686729, 'avgipae_B_BA': 0.9646468437246594, 'pdockq2_B_BA': 0.8285154029164001}
# Processing model 3 for pdb_id: 6r2l...
# {'pdb_id': '6r2l', 'model_number': '3', 'global_plddt': 93.38699323816678, 'cdr1_A': 91.35567567567568, 'cdr2_A': 95.58358974358976, 'cdr3_A': 87.63428571428571, 'cdr1_B': 91.81365853658538, 'cdr2_B': 81.10272727272728, 'cdr3_B': 94.79702127659574, 'iptm_mean': 0.8619999999999999, 'iptm_tcrpmhc': 0.8725, 'pdockq_AB': 0.641, 'pdockq_BA': 0.641, 'avgipae_A_AB': 0.639201919079683, 'avgipae_B_AB': 0.580042299660686, 'pdockq2_A_AB': 0.19015444515312732, 'pdockq2_A_BA': 0.9110471067805787, 'avgipae_A_BA': 0.9766307904575461, 'avgipae_B_BA': 0.9631635863101614, 'pdockq2_B_BA': 0.8173741411499913}
# Processing model 4 for pdb_id: 6r2l...
# {'pdb_id': '6r2l', 'model_number': '4', 'global_plddt': 93.18638016528925, 'cdr1_A': 91.62810810810811, 'cdr2_A': 95.57256410256409, 'cdr3_A': 86.90285714285716, 'cdr1_B': 91.90878048780488, 'cdr2_B': 81.31409090909091, 'cdr3_B': 94.89765957446808, 'iptm_mean': 0.858, 'iptm_tcrpmhc': 0.875, 'pdockq_AB': 0.635, 'pdockq_BA': 0.635, 'avgipae_A_AB': 0.6341343823660799, 'avgipae_B_AB': 0.5676601908331661, 'pdockq2_A_AB': 0.18578620043552269, 'pdockq2_A_BA': 0.9136986736118291, 'avgipae_A_BA': 0.9769688696895891, 'avgipae_B_BA': 0.9623890693868626, 'pdockq2_B_BA': 0.8194890277773414}
# Processing model 2 for pdb_id: 6r2l...
# {'pdb_id': '6r2l', 'model_number': '2', 'global_plddt': 93.15890458302029, 'cdr1_A': 91.56243243243244, 'cdr2_A': 95.26461538461537, 'cdr3_A': 86.16989795918366, 'cdr1_B': 91.77878048780488, 'cdr2_B': 79.97318181818181, 'cdr3_B': 94.62191489361702, 'iptm_mean': 0.8539999999999999, 'iptm_tcrpmhc': 0.87, 'pdockq_AB': 0.642, 'pdockq_BA': 0.642, 'avgipae_A_AB': 0.6272787162115957, 'avgipae_B_AB': 0.5587590908687561, 'pdockq2_A_AB': 0.17528091145381133, 'pdockq2_A_BA': 0.9077208442302768, 'avgipae_A_BA': 0.9749787141398419, 'avgipae_B_BA': 0.9582374681093978, 'pdockq2_B_BA': 0.8006276889183301}
# Processing model 1 for pdb_id: 6avg...
# {'pdb_id': '6avg', 'model_number': '1', 'global_plddt': 89.8840755287009, 'cdr1_A': 67.15142857142857, 'cdr2_A': 76.80097560975611, 'cdr3_A': 75.85079365079366, 'cdr1_B': 83.9525, 'cdr2_B': 84.50037037037038, 'cdr3_B': 71.18303370786516, 'iptm_mean': 0.64, 'iptm_tcrpmhc': 0.5625, 'pdockq_AB': 0.252, 'pdockq_BA': 0.252, 'avgipae_A_AB': 0.39228788255846636, 'avgipae_B_AB': 0.3371207642676019, 'pdockq2_A_AB': 0.021375141656321543, 'pdockq2_A_BA': 0.030448863298704904, 'avgipae_A_BA': 0.47037852253160845, 'avgipae_B_BA': 0.4916625549722727, 'pdockq2_B_BA': 0.03167777765013054}
# Processing model 0 for pdb_id: 6avg...
# {'pdb_id': '6avg', 'model_number': '0', 'global_plddt': 90.27126586102719, 'cdr1_A': 64.40535714285714, 'cdr2_A': 76.43829268292683, 'cdr3_A': 74.17333333333333, 'cdr1_B': 83.081875, 'cdr2_B': 83.84296296296294, 'cdr3_B': 70.50685393258426, 'iptm_mean': 0.6439999999999999, 'iptm_tcrpmhc': 0.5575, 'pdockq_AB': 0.243, 'pdockq_BA': 0.243, 'avgipae_A_AB': 0.38119547256056185, 'avgipae_B_AB': 0.33574588768460334, 'pdockq2_A_AB': 0.019616386421007204, 'pdockq2_A_BA': 0.02963095824263041, 'avgipae_A_BA': 0.468888599426548, 'avgipae_B_BA': 0.5021851806122992, 'pdockq2_B_BA': 0.031005349017399337}
# Processing model 2 for pdb_id: 6avg...
# {'pdb_id': '6avg', 'model_number': '2', 'global_plddt': 89.8140256797583, 'cdr1_A': 64.87875, 'cdr2_A': 75.89780487804877, 'cdr3_A': 73.57968253968254, 'cdr1_B': 82.66250000000001, 'cdr2_B': 83.42999999999999, 'cdr3_B': 70.68213483146067, 'iptm_mean': 0.618, 'iptm_tcrpmhc': 0.5225, 'pdockq_AB': 0.22, 'pdockq_BA': 0.22, 'avgipae_A_AB': 0.35682678145103847, 'avgipae_B_AB': 0.31944652071149304, 'pdockq2_A_AB': 0.016983080644721277, 'pdockq2_A_BA': 0.025832175611088772, 'avgipae_A_BA': 0.4249901172970666, 'avgipae_B_BA': 0.44496942857475447, 'pdockq2_B_BA': 0.02289437757801744}
# Processing model 3 for pdb_id: 6avg...
# {'pdb_id': '6avg', 'model_number': '3', 'global_plddt': 90.00392900302116, 'cdr1_A': 66.43392857142858, 'cdr2_A': 76.27463414634146, 'cdr3_A': 75.99190476190478, 'cdr1_B': 84.299375, 'cdr2_B': 85.69962962962961, 'cdr3_B': 71.49685393258426, 'iptm_mean': 0.65, 'iptm_tcrpmhc': 0.5725, 'pdockq_AB': 0.289, 'pdockq_BA': 0.289, 'avgipae_A_AB': 0.3945476875782639, 'avgipae_B_AB': 0.33135534730443683, 'pdockq2_A_AB': 0.020966769304219795, 'pdockq2_A_BA': 0.04034550832905103, 'avgipae_A_BA': 0.5044118549684516, 'avgipae_B_BA': 0.5087073145129901, 'pdockq2_B_BA': 0.03267757250864709}
# Processing model 4 for pdb_id: 6avg...
# {'pdb_id': '6avg', 'model_number': '4', 'global_plddt': 89.39238670694864, 'cdr1_A': 65.65089285714286, 'cdr2_A': 74.32048780487806, 'cdr3_A': 75.48190476190476, 'cdr1_B': 81.12625, 'cdr2_B': 81.38518518518516, 'cdr3_B': 69.76505617977527, 'iptm_mean': 0.58, 'iptm_tcrpmhc': 0.47, 'pdockq_AB': 0.196, 'pdockq_BA': 0.196, 'avgipae_A_AB': 0.29593337409375525, 'avgipae_B_AB': 0.2829376230143618, 'pdockq2_A_AB': 0.01436030256865042, 'pdockq2_A_BA': 0.020895723391471967, 'avgipae_A_BA': 0.38315346817601903, 'avgipae_B_BA': 0.433221528720577, 'pdockq2_B_BA': 0.022742416980212787}
# Processing model 4 for pdb_id: 2jcc...
# {'pdb_id': '2jcc', 'model_number': '4', 'global_plddt': 90.3250556148103, 'cdr1_A': 77.84551020408163, 'cdr2_A': 82.86083333333333, 'cdr3_A': 77.21322916666666, 'cdr1_B': 86.84043478260871, 'cdr2_B': 81.28318181818182, 'cdr3_B': 86.84106382978725, 'iptm_mean': 0.776, 'iptm_tcrpmhc': 0.7475, 'pdockq_AB': 0.375, 'pdockq_BA': 0.375, 'avgipae_A_AB': 0.5818665202387835, 'avgipae_B_AB': 0.489677893298562, 'pdockq2_A_AB': 0.06334375608605661, 'pdockq2_A_BA': 0.5200408441074005, 'avgipae_A_BA': 0.8624978056145175, 'avgipae_B_BA': 0.7462035209670589, 'pdockq2_B_BA': 0.1424006906039763}
# Processing model 3 for pdb_id: 2jcc...
# {'pdb_id': '2jcc', 'model_number': '3', 'global_plddt': 90.54660521103153, 'cdr1_A': 80.32979591836734, 'cdr2_A': 83.98733333333332, 'cdr3_A': 80.29562499999999, 'cdr1_B': 86.93956521739132, 'cdr2_B': 81.2556818181818, 'cdr3_B': 87.40808510638298, 'iptm_mean': 0.7939999999999999, 'iptm_tcrpmhc': 0.775, 'pdockq_AB': 0.422, 'pdockq_BA': 0.422, 'avgipae_A_AB': 0.6272287206646939, 'avgipae_B_AB': 0.5444661627643456, 'pdockq2_A_AB': 0.08884233978873296, 'pdockq2_A_BA': 0.5937208522565584, 'avgipae_A_BA': 0.8853993644637612, 'avgipae_B_BA': 0.7847996702221975, 'pdockq2_B_BA': 0.19623959495210552}
# Processing model 2 for pdb_id: 2jcc...
# {'pdb_id': '2jcc', 'model_number': '2', 'global_plddt': 90.62733506018589, 'cdr1_A': 79.67408163265306, 'cdr2_A': 84.12100000000001, 'cdr3_A': 79.07760416666666, 'cdr1_B': 87.53608695652174, 'cdr2_B': 82.16704545454546, 'cdr3_B': 87.77255319148937, 'iptm_mean': 0.798, 'iptm_tcrpmhc': 0.7825, 'pdockq_AB': 0.371, 'pdockq_BA': 0.371, 'avgipae_A_AB': 0.6205287602697706, 'avgipae_B_AB': 0.5182760709873764, 'pdockq2_A_AB': 0.08212568299828714, 'pdockq2_A_BA': 0.5811112175418364, 'avgipae_A_BA': 0.8831209628295094, 'avgipae_B_BA': 0.7825231703156957, 'pdockq2_B_BA': 0.18410964849654834}
# Processing model 0 for pdb_id: 2jcc...
# {'pdb_id': '2jcc', 'model_number': '0', 'global_plddt': 90.20486667682462, 'cdr1_A': 76.0538775510204, 'cdr2_A': 82.20483333333333, 'cdr3_A': 75.06322916666666, 'cdr1_B': 86.0841304347826, 'cdr2_B': 79.69204545454546, 'cdr3_B': 85.97978723404256, 'iptm_mean': 0.76, 'iptm_tcrpmhc': 0.7225, 'pdockq_AB': 0.302, 'pdockq_BA': 0.302, 'avgipae_A_AB': 0.5843783330867323, 'avgipae_B_AB': 0.510656942045973, 'pdockq2_A_AB': 0.05646188890749304, 'pdockq2_A_BA': 0.4217421982617084, 'avgipae_A_BA': 0.8260316457162443, 'avgipae_B_BA': 0.7161969928712814, 'pdockq2_B_BA': 0.10527412173150419}
# Processing model 1 for pdb_id: 2jcc...
# {'pdb_id': '2jcc', 'model_number': '1', 'global_plddt': 90.54380618619534, 'cdr1_A': 76.14408163265306, 'cdr2_A': 82.60283333333334, 'cdr3_A': 78.07427083333333, 'cdr1_B': 87.19260869565218, 'cdr2_B': 80.58363636363636, 'cdr3_B': 87.37787234042551, 'iptm_mean': 0.7699999999999999, 'iptm_tcrpmhc': 0.74, 'pdockq_AB': 0.38, 'pdockq_BA': 0.38, 'avgipae_A_AB': 0.5927167419302894, 'avgipae_B_AB': 0.5109916878309476, 'pdockq2_A_AB': 0.06996369663578914, 'pdockq2_A_BA': 0.5195847179914675, 'avgipae_A_BA': 0.8634783355545086, 'avgipae_B_BA': 0.7738789831388566, 'pdockq2_B_BA': 0.17235044882231715}
# Processing model 2 for pdb_id: 8gon...
# {'pdb_id': '8gon', 'model_number': '2', 'global_plddt': 88.45561337165331, 'cdr1_A': 70.52666666666667, 'cdr2_A': 69.73828571428572, 'cdr3_A': 76.41172413793103, 'cdr1_B': 76.6735294117647, 'cdr2_B': 74.24, 'cdr3_B': 67.22435643564356, 'iptm_mean': 0.434, 'iptm_tcrpmhc': 0.1525, 'pdockq_AB': 0.276, 'pdockq_BA': 0.276, 'avgipae_A_AB': 0.11038888911000995, 'avgipae_B_AB': 0.13590468865948152, 'pdockq2_A_AB': 0.00895849241102976, 'pdockq2_A_BA': 0.010793610981875264, 'avgipae_A_BA': 0.14186527674415333, 'avgipae_B_BA': 0.16135855758821843, 'pdockq2_B_BA': 0.010039460959846386}
# Processing model 4 for pdb_id: 8gon...
# {'pdb_id': '8gon', 'model_number': '4', 'global_plddt': 88.31569354106793, 'cdr1_A': 70.8805, 'cdr2_A': 69.08800000000001, 'cdr3_A': 76.62448275862072, 'cdr1_B': 76.41205882352942, 'cdr2_B': 73.89163265306122, 'cdr3_B': 67.23782178217822, 'iptm_mean': 0.42800000000000005, 'iptm_tcrpmhc': 0.14250000000000002, 'pdockq_AB': 0.274, 'pdockq_BA': 0.274, 'avgipae_A_AB': 0.10964332720745258, 'avgipae_B_AB': 0.13037665401929835, 'pdockq2_A_AB': 0.00893399358577009, 'pdockq2_A_BA': 0.010546799796673365, 'avgipae_A_BA': 0.13760411133632255, 'avgipae_B_BA': 0.1581956874098536, 'pdockq2_B_BA': 0.009945375251874087}
# Processing model 3 for pdb_id: 8gon...
# {'pdb_id': '8gon', 'model_number': '3', 'global_plddt': 88.57942520042353, 'cdr1_A': 70.79366666666668, 'cdr2_A': 69.64871428571428, 'cdr3_A': 76.13034482758621, 'cdr1_B': 76.38529411764705, 'cdr2_B': 74.16469387755102, 'cdr3_B': 66.41514851485148, 'iptm_mean': 0.434, 'iptm_tcrpmhc': 0.165, 'pdockq_AB': 0.336, 'pdockq_BA': 0.336, 'avgipae_A_AB': 0.1163478457009479, 'avgipae_B_AB': 0.1337542851413489, 'pdockq2_A_AB': 0.0090511277508507, 'pdockq2_A_BA': 0.010852964641971517, 'avgipae_A_BA': 0.14549812557476444, 'avgipae_B_BA': 0.16641838499640055, 'pdockq2_B_BA': 0.010124251812597494}
# Processing model 1 for pdb_id: 8gon...
# {'pdb_id': '8gon', 'model_number': '1', 'global_plddt': 88.1395204961428, 'cdr1_A': 69.53883333333333, 'cdr2_A': 68.99257142857144, 'cdr3_A': 75.44137931034483, 'cdr1_B': 76.37088235294118, 'cdr2_B': 74.07122448979592, 'cdr3_B': 67.00217821782178, 'iptm_mean': 0.40599999999999997, 'iptm_tcrpmhc': 0.10500000000000001, 'pdockq_AB': 0.17, 'pdockq_BA': 0.17, 'avgipae_A_AB': 0.09550990879667175, 'avgipae_B_AB': 0.11141681277080953, 'pdockq2_A_AB': 0.008628733604952222, 'pdockq2_A_BA': 0.010093987630527223, 'avgipae_A_BA': 0.1182255757126007, 'avgipae_B_BA': 0.13230922748277907, 'pdockq2_B_BA': 0.009292230299415734}
# Processing model 0 for pdb_id: 8gon...
# {'pdb_id': '8gon', 'model_number': '0', 'global_plddt': 88.3511253970655, 'cdr1_A': 70.21633333333334, 'cdr2_A': 69.41485714285714, 'cdr3_A': 76.25103448275861, 'cdr1_B': 76.53617647058825, 'cdr2_B': 73.81102040816327, 'cdr3_B': 67.11613861386138, 'iptm_mean': 0.40599999999999997, 'iptm_tcrpmhc': 0.0975, 'pdockq_AB': 0.134, 'pdockq_BA': 0.134, 'avgipae_A_AB': 0.09468459420491915, 'avgipae_B_AB': 0.10459597009439452, 'pdockq2_A_AB': 0.008573086817036883, 'pdockq2_A_BA': 0.01001080893871215, 'avgipae_A_BA': 0.11629390567390255, 'avgipae_B_BA': 0.128225413345433, 'pdockq2_B_BA': 0.009146793868755408}
# Processing model 2 for pdb_id: 7jwi...
# {'pdb_id': '7jwi', 'model_number': '2', 'global_plddt': 89.09093144560359, 'cdr1_A': 78.92884615384615, 'cdr2_A': 80.96618181818182, 'cdr3_A': 71.20413793103448, 'cdr1_B': 85.74439024390244, 'cdr2_B': 77.07666666666667, 'cdr3_B': 79.49673684210528, 'iptm_mean': 0.624, 'iptm_tcrpmhc': 0.4925, 'pdockq_AB': 0.3, 'pdockq_BA': 0.3, 'avgipae_A_AB': 0.24114138210078204, 'avgipae_B_AB': 0.28239534909348585, 'pdockq2_A_AB': 0.013167670363898779, 'pdockq2_A_BA': 0.0713930083169805, 'avgipae_A_BA': 0.5139151002988054, 'avgipae_B_BA': 0.5258276284146864, 'pdockq2_B_BA': 0.04020963665859032}
# Processing model 4 for pdb_id: 7jwi...
# {'pdb_id': '7jwi', 'model_number': '4', 'global_plddt': 89.03892250372579, 'cdr1_A': 77.71192307692307, 'cdr2_A': 79.84218181818181, 'cdr3_A': 69.70310344827587, 'cdr1_B': 84.63463414634147, 'cdr2_B': 75.81140350877193, 'cdr3_B': 75.93863157894737, 'iptm_mean': 0.5900000000000001, 'iptm_tcrpmhc': 0.43, 'pdockq_AB': 0.159, 'pdockq_BA': 0.159, 'avgipae_A_AB': 0.21744432789905557, 'avgipae_B_AB': 0.2843368630889413, 'pdockq2_A_AB': 0.011174631561755789, 'pdockq2_A_BA': 0.048502697634003944, 'avgipae_A_BA': 0.4542297574830821, 'avgipae_B_BA': 0.4449665320380667, 'pdockq2_B_BA': 0.021950601517765775}
# Processing model 3 for pdb_id: 7jwi...
# {'pdb_id': '7jwi', 'model_number': '3', 'global_plddt': 88.98606110283158, 'cdr1_A': 78.79711538461538, 'cdr2_A': 81.23909090909092, 'cdr3_A': 69.72632183908044, 'cdr1_B': 84.5319512195122, 'cdr2_B': 75.40052631578948, 'cdr3_B': 77.42926315789472, 'iptm_mean': 0.592, 'iptm_tcrpmhc': 0.4275, 'pdockq_AB': 0.324, 'pdockq_BA': 0.324, 'avgipae_A_AB': 0.207116408039485, 'avgipae_B_AB': 0.2707583491238481, 'pdockq2_A_AB': 0.01156623458147539, 'pdockq2_A_BA': 0.03910826057108533, 'avgipae_A_BA': 0.4099205854672913, 'avgipae_B_BA': 0.44021569907498614, 'pdockq2_B_BA': 0.025820590653188275}
# Processing model 1 for pdb_id: 7jwi...
# {'pdb_id': '7jwi', 'model_number': '1', 'global_plddt': 88.66704470938897, 'cdr1_A': 76.84442307692308, 'cdr2_A': 80.12036363636363, 'cdr3_A': 67.08241379310344, 'cdr1_B': 83.30243902439025, 'cdr2_B': 72.99614035087718, 'cdr3_B': 75.45115789473685, 'iptm_mean': 0.544, 'iptm_tcrpmhc': 0.355, 'pdockq_AB': 0.216, 'pdockq_BA': 0.216, 'avgipae_A_AB': 0.18080936784335988, 'avgipae_B_AB': 0.24317045794271844, 'pdockq2_A_AB': 0.01049960537203427, 'pdockq2_A_BA': 0.02578055165998397, 'avgipae_A_BA': 0.3371709473583655, 'avgipae_B_BA': 0.3724256552219138, 'pdockq2_B_BA': 0.018544670877286035}
# Processing model 0 for pdb_id: 7jwi...
# {'pdb_id': '7jwi', 'model_number': '0', 'global_plddt': 88.76642771982117, 'cdr1_A': 77.92557692307693, 'cdr2_A': 79.61345454545456, 'cdr3_A': 68.01149425287356, 'cdr1_B': 83.5551219512195, 'cdr2_B': 74.43105263157894, 'cdr3_B': 75.93757894736842, 'iptm_mean': 0.5740000000000001, 'iptm_tcrpmhc': 0.405, 'pdockq_AB': 0.166, 'pdockq_BA': 0.166, 'avgipae_A_AB': 0.19410504790974725, 'avgipae_B_AB': 0.2439480569321438, 'pdockq2_A_AB': 0.010628349573430142, 'pdockq2_A_BA': 0.03831851851730496, 'avgipae_A_BA': 0.4082757679298986, 'avgipae_B_BA': 0.41423208787105587, 'pdockq2_B_BA': 0.020151905161632892}
# Processing model 1 for pdb_id: 8f5a...
# {'pdb_id': '8f5a', 'model_number': '1', 'global_plddt': 91.63460907848794, 'cdr1_A': 82.69489361702125, 'cdr2_A': 80.05913793103447, 'cdr3_A': 81.11296703296703, 'cdr1_B': 81.13675675675675, 'cdr2_B': 82.41018518518518, 'cdr3_B': 81.90125, 'iptm_mean': 0.608, 'iptm_tcrpmhc': 0.535, 'pdockq_AB': 0.309, 'pdockq_BA': 0.309, 'avgipae_A_AB': 0.33724179224954437, 'avgipae_B_AB': 0.34820482809214554, 'pdockq2_A_AB': 0.019938935239818163, 'pdockq2_A_BA': 0.11388257522944939, 'avgipae_A_BA': 0.6793510991258115, 'avgipae_B_BA': 0.6880441401710882, 'pdockq2_B_BA': 0.1024313969899192}
# Processing model 0 for pdb_id: 8f5a...
# {'pdb_id': '8f5a', 'model_number': '0', 'global_plddt': 91.72834067101867, 'cdr1_A': 83.67744680851064, 'cdr2_A': 81.99275862068967, 'cdr3_A': 81.82307692307693, 'cdr1_B': 83.13297297297298, 'cdr2_B': 83.27537037037038, 'cdr3_B': 83.06984375, 'iptm_mean': 0.65, 'iptm_tcrpmhc': 0.605, 'pdockq_AB': 0.339, 'pdockq_BA': 0.339, 'avgipae_A_AB': 0.3930570064944789, 'avgipae_B_AB': 0.3862395392496649, 'pdockq2_A_AB': 0.027286340044196052, 'pdockq2_A_BA': 0.20935263873999618, 'avgipae_A_BA': 0.7673981471789397, 'avgipae_B_BA': 0.7657396463647991, 'pdockq2_B_BA': 0.1751319150768143}
# Processing model 2 for pdb_id: 8f5a...
# {'pdb_id': '8f5a', 'model_number': '2', 'global_plddt': 91.36371944739638, 'cdr1_A': 82.64553191489362, 'cdr2_A': 80.92068965517241, 'cdr3_A': 79.44912087912088, 'cdr1_B': 81.88648648648648, 'cdr2_B': 82.07851851851852, 'cdr3_B': 81.75265625, 'iptm_mean': 0.6359999999999999, 'iptm_tcrpmhc': 0.5725, 'pdockq_AB': 0.281, 'pdockq_BA': 0.281, 'avgipae_A_AB': 0.3864166248964417, 'avgipae_B_AB': 0.3784668999585145, 'pdockq2_A_AB': 0.025110646452903954, 'pdockq2_A_BA': 0.1231973758911236, 'avgipae_A_BA': 0.6965229489420021, 'avgipae_B_BA': 0.7089296819532501, 'pdockq2_B_BA': 0.11886229396582057}
# Processing model 3 for pdb_id: 8f5a...
# {'pdb_id': '8f5a', 'model_number': '3', 'global_plddt': 91.49603613177472, 'cdr1_A': 82.51404255319149, 'cdr2_A': 81.11827586206897, 'cdr3_A': 80.58769230769231, 'cdr1_B': 81.37378378378378, 'cdr2_B': 82.28000000000002, 'cdr3_B': 81.06578125, 'iptm_mean': 0.64, 'iptm_tcrpmhc': 0.5775, 'pdockq_AB': 0.258, 'pdockq_BA': 0.258, 'avgipae_A_AB': 0.3808457036103013, 'avgipae_B_AB': 0.3649106159959799, 'pdockq2_A_AB': 0.02503495115606803, 'pdockq2_A_BA': 0.11781477557508886, 'avgipae_A_BA': 0.6841393016280111, 'avgipae_B_BA': 0.7076671525257588, 'pdockq2_B_BA': 0.12350775685544084}
# Processing model 4 for pdb_id: 8f5a...
# {'pdb_id': '8f5a', 'model_number': '4', 'global_plddt': 91.41901928040079, 'cdr1_A': 82.15851063829788, 'cdr2_A': 80.39689655172411, 'cdr3_A': 80.0220879120879, 'cdr1_B': 81.5327027027027, 'cdr2_B': 82.17759259259259, 'cdr3_B': 81.05281249999999, 'iptm_mean': 0.626, 'iptm_tcrpmhc': 0.5575, 'pdockq_AB': 0.285, 'pdockq_BA': 0.285, 'avgipae_A_AB': 0.371379722671238, 'avgipae_B_AB': 0.3736461287316711, 'pdockq2_A_AB': 0.023872625316083525, 'pdockq2_A_BA': 0.12946544148115807, 'avgipae_A_BA': 0.6810918400425389, 'avgipae_B_BA': 0.7128065224668376, 'pdockq2_B_BA': 0.12523606871815784}
# Processing model 4 for pdb_id: 7n2p...
# {'pdb_id': '7n2p', 'model_number': '4', 'global_plddt': 88.34046583371895, 'cdr1_A': 73.7968085106383, 'cdr2_A': 75.9148275862069, 'cdr3_A': 71.71935064935064, 'cdr1_B': 80.7840625, 'cdr2_B': 78.70537037037036, 'cdr3_B': 67.3941237113402, 'iptm_mean': 0.542, 'iptm_tcrpmhc': 0.3675, 'pdockq_AB': 0.166, 'pdockq_BA': 0.166, 'avgipae_A_AB': 0.1902551638813045, 'avgipae_B_AB': 0.2329552109289832, 'pdockq2_A_AB': 0.011102469419502294, 'pdockq2_A_BA': 0.017257613260427858, 'avgipae_A_BA': 0.28502017967361776, 'avgipae_B_BA': 0.34818428983926153, 'pdockq2_B_BA': 0.018474014291759915}
# Processing model 3 for pdb_id: 7n2p...
# {'pdb_id': '7n2p', 'model_number': '3', 'global_plddt': 88.58530464291223, 'cdr1_A': 74.37021276595743, 'cdr2_A': 76.64465517241382, 'cdr3_A': 72.67675324675324, 'cdr1_B': 80.69125, 'cdr2_B': 77.85, 'cdr3_B': 67.91494845360825, 'iptm_mean': 0.546, 'iptm_tcrpmhc': 0.3725, 'pdockq_AB': 0.231, 'pdockq_BA': 0.231, 'avgipae_A_AB': 0.1944870425636699, 'avgipae_B_AB': 0.2522037706805158, 'pdockq2_A_AB': 0.011085486174026592, 'pdockq2_A_BA': 0.016940624434707063, 'avgipae_A_BA': 0.27493165199426306, 'avgipae_B_BA': 0.3643523461227027, 'pdockq2_B_BA': 0.018968175342641135}
# Processing model 2 for pdb_id: 7n2p...
# {'pdb_id': '7n2p', 'model_number': '2', 'global_plddt': 88.57606046583372, 'cdr1_A': 75.19765957446809, 'cdr2_A': 76.66362068965519, 'cdr3_A': 72.19662337662338, 'cdr1_B': 81.18, 'cdr2_B': 78.26222222222222, 'cdr3_B': 70.27907216494845, 'iptm_mean': 0.5599999999999999, 'iptm_tcrpmhc': 0.395, 'pdockq_AB': 0.248, 'pdockq_BA': 0.248, 'avgipae_A_AB': 0.22159595808453766, 'avgipae_B_AB': 0.2649947832619903, 'pdockq2_A_AB': 0.012178012312215934, 'pdockq2_A_BA': 0.018734934996520663, 'avgipae_A_BA': 0.29615612801833996, 'avgipae_B_BA': 0.3850757703102023, 'pdockq2_B_BA': 0.02134117430130194}
# Processing model 0 for pdb_id: 7n2p...
# {'pdb_id': '7n2p', 'model_number': '0', 'global_plddt': 88.18159031312663, 'cdr1_A': 73.51234042553192, 'cdr2_A': 76.12172413793103, 'cdr3_A': 71.99558441558443, 'cdr1_B': 80.0703125, 'cdr2_B': 77.87148148148147, 'cdr3_B': 66.88577319587628, 'iptm_mean': 0.532, 'iptm_tcrpmhc': 0.36, 'pdockq_AB': 0.171, 'pdockq_BA': 0.171, 'avgipae_A_AB': 0.19932120913000873, 'avgipae_B_AB': 0.23396952621592146, 'pdockq2_A_AB': 0.011239255429369994, 'pdockq2_A_BA': 0.01686861632725576, 'avgipae_A_BA': 0.2767920394508948, 'avgipae_B_BA': 0.3483315278650222, 'pdockq2_B_BA': 0.017946342030135547}
# Processing model 1 for pdb_id: 7n2p...
# {'pdb_id': '7n2p', 'model_number': '1', 'global_plddt': 88.4435446552522, 'cdr1_A': 73.39510638297874, 'cdr2_A': 75.6103448275862, 'cdr3_A': 72.34974025974027, 'cdr1_B': 79.2440625, 'cdr2_B': 77.01685185185185, 'cdr3_B': 66.55865979381443, 'iptm_mean': 0.532, 'iptm_tcrpmhc': 0.3425, 'pdockq_AB': 0.141, 'pdockq_BA': 0.141, 'avgipae_A_AB': 0.16995095999950138, 'avgipae_B_AB': 0.21024344362024333, 'pdockq2_A_AB': 0.010255417598284976, 'pdockq2_A_BA': 0.01728938819745027, 'avgipae_A_BA': 0.2820565552319864, 'avgipae_B_BA': 0.3538754937207929, 'pdockq2_B_BA': 0.01756400876087277}
# Processing model 0 for pdb_id: 5jhd...
# {'pdb_id': '5jhd', 'model_number': '0', 'global_plddt': 91.34918382684504, 'cdr1_A': 82.98566666666669, 'cdr2_A': 72.857, 'cdr3_A': 87.06453124999999, 'cdr1_B': 89.37256410256411, 'cdr2_B': 83.89282608695653, 'cdr3_B': 85.4081690140845, 'iptm_mean': 0.756, 'iptm_tcrpmhc': 0.7275, 'pdockq_AB': 0.408, 'pdockq_BA': 0.408, 'avgipae_A_AB': 0.5394701225083682, 'avgipae_B_AB': 0.46527094984431516, 'pdockq2_A_AB': 0.05811310475373605, 'pdockq2_A_BA': 0.5700390938193964, 'avgipae_A_BA': 0.8970391919489036, 'avgipae_B_BA': 0.8318253423210781, 'pdockq2_B_BA': 0.25424290735101357}
# Processing model 1 for pdb_id: 5jhd...
# {'pdb_id': '5jhd', 'model_number': '1', 'global_plddt': 91.69783856906658, 'cdr1_A': 82.71699999999997, 'cdr2_A': 71.9497142857143, 'cdr3_A': 86.82578125, 'cdr1_B': 90.42153846153846, 'cdr2_B': 85.28239130434783, 'cdr3_B': 87.03718309859157, 'iptm_mean': 0.764, 'iptm_tcrpmhc': 0.7424999999999999, 'pdockq_AB': 0.424, 'pdockq_BA': 0.424, 'avgipae_A_AB': 0.5350304507616145, 'avgipae_B_AB': 0.46263905327932936, 'pdockq2_A_AB': 0.05788342892599084, 'pdockq2_A_BA': 0.5781619173566207, 'avgipae_A_BA': 0.8986948574720716, 'avgipae_B_BA': 0.8260913866324526, 'pdockq2_B_BA': 0.25416286323029397}
# Processing model 3 for pdb_id: 5jhd...
# {'pdb_id': '5jhd', 'model_number': '3', 'global_plddt': 91.39226514354426, 'cdr1_A': 80.32933333333334, 'cdr2_A': 72.759, 'cdr3_A': 84.56953125, 'cdr1_B': 89.05589743589744, 'cdr2_B': 82.67543478260869, 'cdr3_B': 85.5943661971831, 'iptm_mean': 0.744, 'iptm_tcrpmhc': 0.7125, 'pdockq_AB': 0.408, 'pdockq_BA': 0.408, 'avgipae_A_AB': 0.5201935990959534, 'avgipae_B_AB': 0.46065703240098876, 'pdockq2_A_AB': 0.04633042287702553, 'pdockq2_A_BA': 0.509243749224739, 'avgipae_A_BA': 0.8774364817327003, 'avgipae_B_BA': 0.7983767447667663, 'pdockq2_B_BA': 0.17987799488511455}
# Processing model 4 for pdb_id: 5jhd...
# {'pdb_id': '5jhd', 'model_number': '4', 'global_plddt': 91.3810987524425, 'cdr1_A': 81.12699999999998, 'cdr2_A': 72.74942857142858, 'cdr3_A': 85.6471875, 'cdr1_B': 87.3902564102564, 'cdr2_B': 81.25978260869566, 'cdr3_B': 83.33323943661972, 'iptm_mean': 0.734, 'iptm_tcrpmhc': 0.6950000000000001, 'pdockq_AB': 0.425, 'pdockq_BA': 0.425, 'avgipae_A_AB': 0.49506728446184767, 'avgipae_B_AB': 0.4444014997573033, 'pdockq2_A_AB': 0.043226731220831434, 'pdockq2_A_BA': 0.49008033606339874, 'avgipae_A_BA': 0.872310905769394, 'avgipae_B_BA': 0.8073293206401353, 'pdockq2_B_BA': 0.20347126463333245}
# Processing model 2 for pdb_id: 5jhd...
# {'pdb_id': '5jhd', 'model_number': '2', 'global_plddt': 91.30485795881557, 'cdr1_A': 81.41833333333334, 'cdr2_A': 72.38, 'cdr3_A': 85.58328125, 'cdr1_B': 86.96435897435897, 'cdr2_B': 80.47021739130435, 'cdr3_B': 85.4998591549296, 'iptm_mean': 0.726, 'iptm_tcrpmhc': 0.6825, 'pdockq_AB': 0.361, 'pdockq_BA': 0.361, 'avgipae_A_AB': 0.4655370080523338, 'avgipae_B_AB': 0.42811976413064456, 'pdockq2_A_AB': 0.037398102606346996, 'pdockq2_A_BA': 0.4914474483031066, 'avgipae_A_BA': 0.8734961061396789, 'avgipae_B_BA': 0.8097059719705921, 'pdockq2_B_BA': 0.20530538660703887}
# Processing model 2 for pdb_id: 6vrm...
# {'pdb_id': '6vrm', 'model_number': '2', 'global_plddt': 90.97382294378924, 'cdr1_A': 82.345, 'cdr2_A': 71.31771428571429, 'cdr3_A': 85.20378048780489, 'cdr1_B': 88.631, 'cdr2_B': 83.70162162162163, 'cdr3_B': 91.5859595959596, 'iptm_mean': 0.67, 'iptm_tcrpmhc': 0.5875, 'pdockq_AB': 0.27, 'pdockq_BA': 0.27, 'avgipae_A_AB': 0.34743755724697745, 'avgipae_B_AB': 0.3031376044765585, 'pdockq2_A_AB': 0.0242907160559833, 'pdockq2_A_BA': 0.35536596216357885, 'avgipae_A_BA': 0.7965884635939245, 'avgipae_B_BA': 0.7694606144362782, 'pdockq2_B_BA': 0.22115986095415738}
# Processing model 3 for pdb_id: 6vrm...
# {'pdb_id': '6vrm', 'model_number': '3', 'global_plddt': 91.18946852504213, 'cdr1_A': 82.98425, 'cdr2_A': 70.91828571428572, 'cdr3_A': 85.76987804878048, 'cdr1_B': 89.8495, 'cdr2_B': 85.51081081081081, 'cdr3_B': 91.86676767676767, 'iptm_mean': 0.692, 'iptm_tcrpmhc': 0.6225, 'pdockq_AB': 0.298, 'pdockq_BA': 0.298, 'avgipae_A_AB': 0.3661282195925175, 'avgipae_B_AB': 0.302746972664167, 'pdockq2_A_AB': 0.028012750061744536, 'pdockq2_A_BA': 0.44854922765622934, 'avgipae_A_BA': 0.8338629251102704, 'avgipae_B_BA': 0.8108314915220697, 'pdockq2_B_BA': 0.3026513979762938}
# Processing model 4 for pdb_id: 6vrm...
# {'pdb_id': '6vrm', 'model_number': '4', 'global_plddt': 91.00348751723082, 'cdr1_A': 81.204, 'cdr2_A': 71.35514285714287, 'cdr3_A': 83.97731707317074, 'cdr1_B': 88.88050000000001, 'cdr2_B': 84.33675675675676, 'cdr3_B': 91.34060606060605, 'iptm_mean': 0.666, 'iptm_tcrpmhc': 0.575, 'pdockq_AB': 0.275, 'pdockq_BA': 0.275, 'avgipae_A_AB': 0.3481632405253395, 'avgipae_B_AB': 0.2994715082833247, 'pdockq2_A_AB': 0.023680685231029508, 'pdockq2_A_BA': 0.3146525576573579, 'avgipae_A_BA': 0.7788185371196863, 'avgipae_B_BA': 0.7583840209427636, 'pdockq2_B_BA': 0.19566326721159527}
# Processing model 1 for pdb_id: 6vrm...
# {'pdb_id': '6vrm', 'model_number': '1', 'global_plddt': 90.88122070761219, 'cdr1_A': 80.6815, 'cdr2_A': 70.08057142857143, 'cdr3_A': 83.88536585365854, 'cdr1_B': 87.85375, 'cdr2_B': 83.64135135135136, 'cdr3_B': 90.98777777777777, 'iptm_mean': 0.654, 'iptm_tcrpmhc': 0.5575, 'pdockq_AB': 0.249, 'pdockq_BA': 0.249, 'avgipae_A_AB': 0.3252953532620417, 'avgipae_B_AB': 0.28585257394021824, 'pdockq2_A_AB': 0.021028936203976323, 'pdockq2_A_BA': 0.28815625242638215, 'avgipae_A_BA': 0.7651198385352204, 'avgipae_B_BA': 0.7541141342551455, 'pdockq2_B_BA': 0.18501501202410417}
# Processing model 0 for pdb_id: 6vrm...
# {'pdb_id': '6vrm', 'model_number': '0', 'global_plddt': 90.93629805483228, 'cdr1_A': 82.1125, 'cdr2_A': 70.29885714285714, 'cdr3_A': 84.81487804878049, 'cdr1_B': 88.78725, 'cdr2_B': 84.15567567567568, 'cdr3_B': 91.3418181818182, 'iptm_mean': 0.6639999999999999, 'iptm_tcrpmhc': 0.5775, 'pdockq_AB': 0.314, 'pdockq_BA': 0.314, 'avgipae_A_AB': 0.3330762899437741, 'avgipae_B_AB': 0.29251613694497597, 'pdockq2_A_AB': 0.022215658864852966, 'pdockq2_A_BA': 0.3247305818684482, 'avgipae_A_BA': 0.7821494613985923, 'avgipae_B_BA': 0.7557650659717436, 'pdockq2_B_BA': 0.19599343906517483}
# Processing model 4 for pdb_id: 7q9a...
# {'pdb_id': '7q9a', 'model_number': '4', 'global_plddt': 91.64796832579187, 'cdr1_A': 88.92568181818181, 'cdr2_A': 89.7591304347826, 'cdr3_A': 90.52258620689655, 'cdr1_B': 89.3365, 'cdr2_B': 87.58068965517242, 'cdr3_B': 90.23520833333333, 'iptm_mean': 0.806, 'iptm_tcrpmhc': 0.8125, 'pdockq_AB': 0.591, 'pdockq_BA': 0.591, 'avgipae_A_AB': 0.4635548137612609, 'avgipae_B_AB': 0.342994521116514, 'pdockq2_A_AB': 0.056120201131347615, 'pdockq2_A_BA': 0.8065766055701199, 'avgipae_A_BA': 0.9579431598742304, 'avgipae_B_BA': 0.9299732904696323, 'pdockq2_B_BA': 0.6409560385160363}
# Processing model 3 for pdb_id: 7q9a...
# {'pdb_id': '7q9a', 'model_number': '3', 'global_plddt': 91.54624132730014, 'cdr1_A': 86.555, 'cdr2_A': 88.54673913043477, 'cdr3_A': 90.21258620689656, 'cdr1_B': 88.85925, 'cdr2_B': 88.07896551724137, 'cdr3_B': 89.81479166666668, 'iptm_mean': 0.8019999999999999, 'iptm_tcrpmhc': 0.8049999999999999, 'pdockq_AB': 0.548, 'pdockq_BA': 0.548, 'avgipae_A_AB': 0.4457879444323885, 'avgipae_B_AB': 0.34118331284663433, 'pdockq2_A_AB': 0.04955976450939282, 'pdockq2_A_BA': 0.8020129583498643, 'avgipae_A_BA': 0.9584855181764664, 'avgipae_B_BA': 0.9320849214508918, 'pdockq2_B_BA': 0.6300397274934948}
# Processing model 2 for pdb_id: 7q9a...
# {'pdb_id': '7q9a', 'model_number': '2', 'global_plddt': 91.64302714932127, 'cdr1_A': 88.73113636363635, 'cdr2_A': 91.2586956521739, 'cdr3_A': 90.72620689655172, 'cdr1_B': 88.94725000000001, 'cdr2_B': 88.08103448275861, 'cdr3_B': 90.33666666666666, 'iptm_mean': 0.8160000000000001, 'iptm_tcrpmhc': 0.8225, 'pdockq_AB': 0.576, 'pdockq_BA': 0.576, 'avgipae_A_AB': 0.4723840137077839, 'avgipae_B_AB': 0.36341957598068547, 'pdockq2_A_AB': 0.06039754674061389, 'pdockq2_A_BA': 0.8332634424537267, 'avgipae_A_BA': 0.9640263522636094, 'avgipae_B_BA': 0.9409541862907075, 'pdockq2_B_BA': 0.6810210412663382}
# Processing model 0 for pdb_id: 7q9a...
# {'pdb_id': '7q9a', 'model_number': '0', 'global_plddt': 91.90831221719456, 'cdr1_A': 90.23863636363636, 'cdr2_A': 93.38499999999998, 'cdr3_A': 89.89724137931034, 'cdr1_B': 86.06025, 'cdr2_B': 86.13137931034481, 'cdr3_B': 89.4171875, 'iptm_mean': 0.82, 'iptm_tcrpmhc': 0.83, 'pdockq_AB': 0.545, 'pdockq_BA': 0.545, 'avgipae_A_AB': 0.4994939083278271, 'avgipae_B_AB': 0.3996264209133849, 'pdockq2_A_AB': 0.06957673478455051, 'pdockq2_A_BA': 0.8221323667026591, 'avgipae_A_BA': 0.964359566106171, 'avgipae_B_BA': 0.9417371407199973, 'pdockq2_B_BA': 0.6682422929195226}
# Processing model 1 for pdb_id: 7q9a...
# {'pdb_id': '7q9a', 'model_number': '1', 'global_plddt': 91.76154298642534, 'cdr1_A': 84.15204545454547, 'cdr2_A': 87.23086956521739, 'cdr3_A': 88.17827586206896, 'cdr1_B': 88.78925000000001, 'cdr2_B': 89.38000000000002, 'cdr3_B': 88.43864583333334, 'iptm_mean': 0.784, 'iptm_tcrpmhc': 0.7775, 'pdockq_AB': 0.564, 'pdockq_BA': 0.564, 'avgipae_A_AB': 0.4280334161892809, 'avgipae_B_AB': 0.3338081248204227, 'pdockq2_A_AB': 0.042084024610198376, 'pdockq2_A_BA': 0.7389369084457126, 'avgipae_A_BA': 0.9453884887545584, 'avgipae_B_BA': 0.9104697398415629, 'pdockq2_B_BA': 0.5348653520309082}
# Processing model 3 for pdb_id: 5nmf...
# {'pdb_id': '5nmf', 'model_number': '3', 'global_plddt': 93.68456574185767, 'cdr1_A': 88.46068181818181, 'cdr2_A': 94.51065217391306, 'cdr3_A': 94.89604938271604, 'cdr1_B': 94.26078947368421, 'cdr2_B': 92.99533333333332, 'cdr3_B': 96.20482758620689, 'iptm_mean': 0.858, 'iptm_tcrpmhc': 0.8674999999999999, 'pdockq_AB': 0.583, 'pdockq_BA': 0.583, 'avgipae_A_AB': 0.6173342401805818, 'avgipae_B_AB': 0.5507417377167281, 'pdockq2_A_AB': 0.1759494245399091, 'pdockq2_A_BA': 0.904700516789568, 'avgipae_A_BA': 0.9765092895698726, 'avgipae_B_BA': 0.968666686520278, 'pdockq2_B_BA': 0.8589198127585632}
# Processing model 4 for pdb_id: 5nmf...
# {'pdb_id': '5nmf', 'model_number': '4', 'global_plddt': 93.65178679131483, 'cdr1_A': 87.96136363636364, 'cdr2_A': 93.87456521739132, 'cdr3_A': 94.20469135802469, 'cdr1_B': 93.49552631578948, 'cdr2_B': 91.52550000000001, 'cdr3_B': 95.57436781609196, 'iptm_mean': 0.85, 'iptm_tcrpmhc': 0.86, 'pdockq_AB': 0.553, 'pdockq_BA': 0.553, 'avgipae_A_AB': 0.6055434176935464, 'avgipae_B_AB': 0.5297712133676322, 'pdockq2_A_AB': 0.15998849480323388, 'pdockq2_A_BA': 0.8894600088458252, 'avgipae_A_BA': 0.9739877835099695, 'avgipae_B_BA': 0.9640441088499807, 'pdockq2_B_BA': 0.8358818075315372}
# Processing model 2 for pdb_id: 5nmf...
# {'pdb_id': '5nmf', 'model_number': '2', 'global_plddt': 93.67561067551267, 'cdr1_A': 88.4525, 'cdr2_A': 94.27434782608695, 'cdr3_A': 94.81024691358026, 'cdr1_B': 93.91184210526315, 'cdr2_B': 91.78899999999999, 'cdr3_B': 95.93206896551725, 'iptm_mean': 0.8539999999999999, 'iptm_tcrpmhc': 0.8674999999999999, 'pdockq_AB': 0.576, 'pdockq_BA': 0.576, 'avgipae_A_AB': 0.6148719992242935, 'avgipae_B_AB': 0.5384519461800145, 'pdockq2_A_AB': 0.1721575414855068, 'pdockq2_A_BA': 0.9054943148146244, 'avgipae_A_BA': 0.977077070046009, 'avgipae_B_BA': 0.9674419880940873, 'pdockq2_B_BA': 0.852505259849288}
# Processing model 0 for pdb_id: 5nmf...
# {'pdb_id': '5nmf', 'model_number': '0', 'global_plddt': 93.63984770808202, 'cdr1_A': 88.44522727272728, 'cdr2_A': 94.39934782608694, 'cdr3_A': 94.85444444444444, 'cdr1_B': 94.035, 'cdr2_B': 93.01016666666668, 'cdr3_B': 96.1283908045977, 'iptm_mean': 0.86, 'iptm_tcrpmhc': 0.875, 'pdockq_AB': 0.583, 'pdockq_BA': 0.583, 'avgipae_A_AB': 0.6201942431717579, 'avgipae_B_AB': 0.543903743175678, 'pdockq2_A_AB': 0.17869605967203325, 'pdockq2_A_BA': 0.9083349214090599, 'avgipae_A_BA': 0.9777791998274763, 'avgipae_B_BA': 0.9686486654537202, 'pdockq2_B_BA': 0.8578648291674864}
# Processing model 1 for pdb_id: 5nmf...
# {'pdb_id': '5nmf', 'model_number': '1', 'global_plddt': 93.645701145959, 'cdr1_A': 87.91068181818183, 'cdr2_A': 94.33369565217392, 'cdr3_A': 94.8895061728395, 'cdr1_B': 94.18263157894735, 'cdr2_B': 92.65683333333331, 'cdr3_B': 96.08770114942527, 'iptm_mean': 0.8539999999999999, 'iptm_tcrpmhc': 0.8674999999999999, 'pdockq_AB': 0.578, 'pdockq_BA': 0.578, 'avgipae_A_AB': 0.6101642248830162, 'avgipae_B_AB': 0.534674562200217, 'pdockq2_A_AB': 0.1673364989733442, 'pdockq2_A_BA': 0.9061217689659431, 'avgipae_A_BA': 0.9768573968415887, 'avgipae_B_BA': 0.9673975800856404, 'pdockq2_B_BA': 0.8525398179486927}
# Processing model 0 for pdb_id: 3tjh...
# {'pdb_id': '3tjh', 'model_number': '0', 'global_plddt': 91.47349098196392, 'cdr1_A': 71.61551020408162, 'cdr2_A': 88.4068253968254, 'cdr3_A': 78.68894736842105, 'cdr1_B': 87.51840909090907, 'cdr2_B': 87.41897435897437, 'cdr3_B': 90.97414285714287, 'iptm_mean': 0.8, 'iptm_tcrpmhc': 0.7475, 'pdockq_AB': 0.699, 'pdockq_BA': 0.699, 'avgipae_A_AB': 0.48478560723748343, 'avgipae_B_AB': 0.5927715685242441, 'pdockq2_A_AB': 0.07392433903740162, 'pdockq2_A_BA': 0.7418469598039764, 'avgipae_A_BA': 0.9474575241547459, 'avgipae_B_BA': 0.9645871154411387, 'pdockq2_B_BA': 0.8246274779999293}
# Processing model 1 for pdb_id: 3tjh...
# {'pdb_id': '3tjh', 'model_number': '1', 'global_plddt': 91.82911022044088, 'cdr1_A': 72.16816326530612, 'cdr2_A': 89.37000000000002, 'cdr3_A': 81.66921052631578, 'cdr1_B': 88.52204545454545, 'cdr2_B': 88.84076923076921, 'cdr3_B': 91.97742857142858, 'iptm_mean': 0.8200000000000001, 'iptm_tcrpmhc': 0.775, 'pdockq_AB': 0.699, 'pdockq_BA': 0.699, 'avgipae_A_AB': 0.5089591568930893, 'avgipae_B_AB': 0.6142305743790462, 'pdockq2_A_AB': 0.08785637137568879, 'pdockq2_A_BA': 0.7650093789336749, 'avgipae_A_BA': 0.9520149768210145, 'avgipae_B_BA': 0.9673305932275943, 'pdockq2_B_BA': 0.8443886807408993}
# Processing model 4 for pdb_id: 3tjh...
# {'pdb_id': '3tjh', 'model_number': '4', 'global_plddt': 91.69830460921844, 'cdr1_A': 72.52, 'cdr2_A': 87.23698412698413, 'cdr3_A': 79.8992105263158, 'cdr1_B': 89.53704545454544, 'cdr2_B': 89.27179487179485, 'cdr3_B': 92.08128571428571, 'iptm_mean': 0.8325, 'iptm_tcrpmhc': 0.7875, 'pdockq_AB': 0.698, 'pdockq_BA': 0.698, 'avgipae_A_AB': 0.5295370054394387, 'avgipae_B_AB': 0.6228142076825278, 'pdockq2_A_AB': 0.09957423345119946, 'pdockq2_A_BA': 0.7698820405615904, 'avgipae_A_BA': 0.9536254712119263, 'avgipae_B_BA': 0.9679322214264833, 'pdockq2_B_BA': 0.8428874819200045}
# Processing model 3 for pdb_id: 3tjh...
# {'pdb_id': '3tjh', 'model_number': '3', 'global_plddt': 90.82680761523046, 'cdr1_A': 69.04795918367347, 'cdr2_A': 86.65158730158733, 'cdr3_A': 76.59381578947368, 'cdr1_B': 87.69818181818181, 'cdr2_B': 86.52282051282052, 'cdr3_B': 90.88300000000001, 'iptm_mean': 0.785, 'iptm_tcrpmhc': 0.73, 'pdockq_AB': 0.697, 'pdockq_BA': 0.697, 'avgipae_A_AB': 0.45757963983752376, 'avgipae_B_AB': 0.5567570699428291, 'pdockq2_A_AB': 0.06140333136375133, 'pdockq2_A_BA': 0.701316502694224, 'avgipae_A_BA': 0.9381826541010585, 'avgipae_B_BA': 0.957047557223622, 'pdockq2_B_BA': 0.7966425475198479}
# Processing model 2 for pdb_id: 3tjh...
# {'pdb_id': '3tjh', 'model_number': '2', 'global_plddt': 92.03907214428857, 'cdr1_A': 74.18020408163265, 'cdr2_A': 89.89095238095238, 'cdr3_A': 79.89513157894737, 'cdr1_B': 90.35545454545455, 'cdr2_B': 90.48871794871795, 'cdr3_B': 93.04985714285714, 'iptm_mean': 0.8574999999999999, 'iptm_tcrpmhc': 0.825, 'pdockq_AB': 0.701, 'pdockq_BA': 0.701, 'avgipae_A_AB': 0.5582861657281301, 'avgipae_B_AB': 0.652602724435788, 'pdockq2_A_AB': 0.12118510137119069, 'pdockq2_A_BA': 0.7774787365956315, 'avgipae_A_BA': 0.956010234701783, 'avgipae_B_BA': 0.971590470967664, 'pdockq2_B_BA': 0.8604638494231052}
# Processing model 4 for pdb_id: 4qrr...
# {'pdb_id': '4qrr', 'model_number': '4', 'global_plddt': 93.71907265917604, 'cdr1_A': 95.0956338028169, 'cdr2_A': 93.27641509433961, 'cdr3_A': 95.61651162790699, 'cdr1_B': 93.84027027027027, 'cdr2_B': 95.13444444444447, 'cdr3_B': 95.06834951456311, 'iptm_mean': 0.86, 'iptm_tcrpmhc': 0.8674999999999999, 'pdockq_AB': 0.434, 'pdockq_BA': 0.434, 'avgipae_A_AB': 0.7176953795980421, 'avgipae_B_AB': 0.5710737151339371, 'pdockq2_A_AB': 0.3029706544707967, 'pdockq2_A_BA': 0.8484543948011067, 'avgipae_A_BA': 0.9674348208474539, 'avgipae_B_BA': 0.9637688697099932, 'pdockq2_B_BA': 0.8292864672240299}
# Processing model 3 for pdb_id: 4qrr...
# {'pdb_id': '4qrr', 'model_number': '3', 'global_plddt': 93.59410936329589, 'cdr1_A': 94.69239436619716, 'cdr2_A': 93.05018867924528, 'cdr3_A': 95.6013953488372, 'cdr1_B': 93.65297297297298, 'cdr2_B': 95.05925925925928, 'cdr3_B': 94.8740776699029, 'iptm_mean': 0.8480000000000001, 'iptm_tcrpmhc': 0.85, 'pdockq_AB': 0.36, 'pdockq_BA': 0.36, 'avgipae_A_AB': 0.6974882411488708, 'avgipae_B_AB': 0.5575521281612354, 'pdockq2_A_AB': 0.2658642614590661, 'pdockq2_A_BA': 0.8376399401677578, 'avgipae_A_BA': 0.9640623912085144, 'avgipae_B_BA': 0.9577865660633054, 'pdockq2_B_BA': 0.80546667558391}
# Processing model 2 for pdb_id: 4qrr...
# {'pdb_id': '4qrr', 'model_number': '2', 'global_plddt': 93.6774277153558, 'cdr1_A': 94.87112676056337, 'cdr2_A': 93.13471698113206, 'cdr3_A': 95.81651162790696, 'cdr1_B': 93.9172972972973, 'cdr2_B': 95.05814814814815, 'cdr3_B': 94.93757281553394, 'iptm_mean': 0.858, 'iptm_tcrpmhc': 0.86, 'pdockq_AB': 0.427, 'pdockq_BA': 0.427, 'avgipae_A_AB': 0.7028810705477788, 'avgipae_B_AB': 0.5706312094538313, 'pdockq2_A_AB': 0.27858528531577903, 'pdockq2_A_BA': 0.8443404892349679, 'avgipae_A_BA': 0.9654046242644784, 'avgipae_B_BA': 0.9618348232697352, 'pdockq2_B_BA': 0.8234916330111393}
# Processing model 0 for pdb_id: 4qrr...
# {'pdb_id': '4qrr', 'model_number': '0', 'global_plddt': 93.74490486891385, 'cdr1_A': 95.08957746478873, 'cdr2_A': 93.27075471698114, 'cdr3_A': 95.80000000000001, 'cdr1_B': 93.93810810810812, 'cdr2_B': 95.05907407407406, 'cdr3_B': 95.0826213592233, 'iptm_mean': 0.858, 'iptm_tcrpmhc': 0.865, 'pdockq_AB': 0.444, 'pdockq_BA': 0.444, 'avgipae_A_AB': 0.7087319430128293, 'avgipae_B_AB': 0.5784065871825983, 'pdockq2_A_AB': 0.28855601464364383, 'pdockq2_A_BA': 0.8474284234704939, 'avgipae_A_BA': 0.9660076325298478, 'avgipae_B_BA': 0.9635605867115673, 'pdockq2_B_BA': 0.8288601817341664}
# Processing model 1 for pdb_id: 4qrr...
# {'pdb_id': '4qrr', 'model_number': '1', 'global_plddt': 93.73264269662921, 'cdr1_A': 95.01971830985916, 'cdr2_A': 93.0164150943396, 'cdr3_A': 95.73325581395348, 'cdr1_B': 94.00135135135136, 'cdr2_B': 95.16148148148149, 'cdr3_B': 94.93203883495146, 'iptm_mean': 0.858, 'iptm_tcrpmhc': 0.86, 'pdockq_AB': 0.435, 'pdockq_BA': 0.435, 'avgipae_A_AB': 0.7127759302632958, 'avgipae_B_AB': 0.5815774087458805, 'pdockq2_A_AB': 0.29195375625220593, 'pdockq2_A_BA': 0.8526219932604053, 'avgipae_A_BA': 0.966650467587403, 'avgipae_B_BA': 0.9611011399185488, 'pdockq2_B_BA': 0.8178664945034956}
# Processing model 4 for pdb_id: 2esv...
# {'pdb_id': '2esv', 'model_number': '4', 'global_plddt': 92.38776681342037, 'cdr1_A': 87.46722222222223, 'cdr2_A': 88.41540540540541, 'cdr3_A': 89.11134831460674, 'cdr1_B': 94.96638888888889, 'cdr2_B': 93.56529411764706, 'cdr3_B': 93.28333333333335, 'iptm_mean': 0.842, 'iptm_tcrpmhc': 0.845, 'pdockq_AB': 0.471, 'pdockq_BA': 0.471, 'avgipae_A_AB': 0.660093404490035, 'avgipae_B_AB': 0.5638165193618566, 'pdockq2_A_AB': 0.18666503783977176, 'pdockq2_A_BA': 0.8542577946516342, 'avgipae_A_BA': 0.967172688545603, 'avgipae_B_BA': 0.943691335458133, 'pdockq2_B_BA': 0.6956515076752128}
# Processing model 3 for pdb_id: 2esv...
# {'pdb_id': '2esv', 'model_number': '3', 'global_plddt': 92.32763473508426, 'cdr1_A': 86.83592592592592, 'cdr2_A': 88.77432432432435, 'cdr3_A': 89.11011235955056, 'cdr1_B': 94.92333333333333, 'cdr2_B': 93.55627450980391, 'cdr3_B': 93.1648148148148, 'iptm_mean': 0.8380000000000001, 'iptm_tcrpmhc': 0.8375, 'pdockq_AB': 0.48, 'pdockq_BA': 0.48, 'avgipae_A_AB': 0.6558573501103542, 'avgipae_B_AB': 0.5655563594618301, 'pdockq2_A_AB': 0.18106115104905035, 'pdockq2_A_BA': 0.8446726802207851, 'avgipae_A_BA': 0.964794618303136, 'avgipae_B_BA': 0.9418498896999085, 'pdockq2_B_BA': 0.6880792098708208}
# ...
# Processing model 0 for pdb_id: 2p5e...
# {'pdb_id': '2p5e', 'model_number': '0', 'global_plddt': 94.64347892253843, 'cdr1_A': 97.16425531914896, 'cdr2_A': 91.57, 'cdr3_A': 97.5382828282828, 'cdr1_B': 97.77170212765957, 'cdr2_B': 95.48238095238096, 'cdr3_B': 97.34761363636363, 'iptm_mean': 0.892, 'iptm_tcrpmhc': 0.91, 'pdockq_AB': 0.613, 'pdockq_BA': 0.613, 'avgipae_A_AB': 0.6621596145062091, 'avgipae_B_AB': 0.5607275143046787, 'pdockq2_A_AB': 0.2472168286995523, 'pdockq2_A_BA': 0.9445674540950834, 'avgipae_A_BA': 0.9860259170942672, 'avgipae_B_BA': 0.9822863758722202, 'pdockq2_B_BA': 0.9255749802289712}
# Processing model 1 for pdb_id: 2p5e...
# {'pdb_id': '2p5e', 'model_number': '1', 'global_plddt': 94.65780398721657, 'cdr1_A': 97.28404255319145, 'cdr2_A': 91.78384615384614, 'cdr3_A': 97.53858585858589, 'cdr1_B': 97.76404255319149, 'cdr2_B': 95.31357142857142, 'cdr3_B': 97.38465909090907, 'iptm_mean': 0.8939999999999999, 'iptm_tcrpmhc': 0.9125, 'pdockq_AB': 0.595, 'pdockq_BA': 0.595, 'avgipae_A_AB': 0.6634938537471076, 'avgipae_B_AB': 0.5670357666060913, 'pdockq2_A_AB': 0.24942186099891464, 'pdockq2_A_BA': 0.9448523719463072, 'avgipae_A_BA': 0.9863104544625102, 'avgipae_B_BA': 0.9828643572108531, 'pdockq2_B_BA': 0.9272842893768768}
# Processing model 4 for pdb_id: 2p5e...
# {'pdb_id': '2p5e', 'model_number': '4', 'global_plddt': 94.49015522751485, 'cdr1_A': 97.04787234042553, 'cdr2_A': 91.55523076923077, 'cdr3_A': 97.36434343434345, 'cdr1_B': 97.55744680851065, 'cdr2_B': 95.00761904761904, 'cdr3_B': 97.13818181818182, 'iptm_mean': 0.882, 'iptm_tcrpmhc': 0.9, 'pdockq_AB': 0.597, 'pdockq_BA': 0.597, 'avgipae_A_AB': 0.6394024818268901, 'avgipae_B_AB': 0.5397807304818031, 'pdockq2_A_AB': 0.21455412868749674, 'pdockq2_A_BA': 0.9393245515771095, 'avgipae_A_BA': 0.9842029690565113, 'avgipae_B_BA': 0.9797191450694783, 'pdockq2_B_BA': 0.916847453902883}
# Processing model 3 for pdb_id: 2p5e...
# {'pdb_id': '2p5e', 'model_number': '3', 'global_plddt': 94.56734439202557, 'cdr1_A': 97.03914893617019, 'cdr2_A': 91.40353846153846, 'cdr3_A': 97.38696969696969, 'cdr1_B': 97.73021276595745, 'cdr2_B': 95.30333333333333, 'cdr3_B': 97.26022727272726, 'iptm_mean': 0.884, 'iptm_tcrpmhc': 0.905, 'pdockq_AB': 0.601, 'pdockq_BA': 0.601, 'avgipae_A_AB': 0.637534596307925, 'avgipae_B_AB': 0.545867755680629, 'pdockq2_A_AB': 0.2130442039270595, 'pdockq2_A_BA': 0.9408202205209163, 'avgipae_A_BA': 0.9847579782046557, 'avgipae_B_BA': 0.9815439993252697, 'pdockq2_B_BA': 0.9226749445932363}
# Processing model 2 for pdb_id: 2p5e...
# {'pdb_id': '2p5e', 'model_number': '2', 'global_plddt': 94.56581646629128, 'cdr1_A': 97.13148936170214, 'cdr2_A': 91.71692307692308, 'cdr3_A': 97.48545454545456, 'cdr1_B': 97.73446808510636, 'cdr2_B': 95.40619047619047, 'cdr3_B': 97.33977272727275, 'iptm_mean': 0.884, 'iptm_tcrpmhc': 0.905, 'pdockq_AB': 0.602, 'pdockq_BA': 0.602, 'avgipae_A_AB': 0.6505159552620263, 'avgipae_B_AB': 0.5407254700756193, 'pdockq2_A_AB': 0.23073784232621794, 'pdockq2_A_BA': 0.942641242684228, 'avgipae_A_BA': 0.9852881973780709, 'avgipae_B_BA': 0.9813620054564055, 'pdockq2_B_BA': 0.9234941117503124}
# Processing model 0 for pdb_id: 5m01...
# {'pdb_id': '5m01', 'model_number': '0', 'global_plddt': 92.76255828220859, 'cdr1_A': 96.31384615384614, 'cdr2_A': 95.1669230769231, 'cdr3_A': 95.4088, 'cdr1_B': 95.12847826086956, 'cdr2_B': 94.25863636363637, 'cdr3_B': 96.62964285714284, 'iptm_mean': 0.8539999999999999, 'iptm_tcrpmhc': 0.8725, 'pdockq_AB': 0.482, 'pdockq_BA': 0.482, 'avgipae_A_AB': 0.6510279509317564, 'avgipae_B_AB': 0.5604430900256919, 'pdockq2_A_AB': 0.2231827641666038, 'pdockq2_A_BA': 0.9304695855467112, 'avgipae_A_BA': 0.98101975426391, 'avgipae_B_BA': 0.9715384498002396, 'pdockq2_B_BA': 0.8843814256006256}
# Processing model 1 for pdb_id: 5m01...
# {'pdb_id': '5m01', 'model_number': '1', 'global_plddt': 92.89311042944784, 'cdr1_A': 96.35557692307692, 'cdr2_A': 95.11538461538461, 'cdr3_A': 95.52146666666667, 'cdr1_B': 95.0769565217391, 'cdr2_B': 94.3990909090909, 'cdr3_B': 96.72249999999998, 'iptm_mean': 0.8560000000000001, 'iptm_tcrpmhc': 0.8775, 'pdockq_AB': 0.498, 'pdockq_BA': 0.498, 'avgipae_A_AB': 0.6658816790379561, 'avgipae_B_AB': 0.5682467662314746, 'pdockq2_A_AB': 0.24435668687958934, 'pdockq2_A_BA': 0.9321997512896306, 'avgipae_A_BA': 0.9814500589325662, 'avgipae_B_BA': 0.9728104977133405, 'pdockq2_B_BA': 0.8889430238364409}
# Processing model 4 for pdb_id: 5m01...
# {'pdb_id': '5m01', 'model_number': '4', 'global_plddt': 92.82769018404909, 'cdr1_A': 96.21576923076921, 'cdr2_A': 95.04596153846153, 'cdr3_A': 95.52813333333333, 'cdr1_B': 95.14978260869566, 'cdr2_B': 94.05818181818181, 'cdr3_B': 96.73976190476189, 'iptm_mean': 0.8539999999999999, 'iptm_tcrpmhc': 0.875, 'pdockq_AB': 0.484, 'pdockq_BA': 0.484, 'avgipae_A_AB': 0.6470249386452748, 'avgipae_B_AB': 0.5541477601151558, 'pdockq2_A_AB': 0.21867055194514587, 'pdockq2_A_BA': 0.930749907945189, 'avgipae_A_BA': 0.9811807725056927, 'avgipae_B_BA': 0.9726792832678375, 'pdockq2_B_BA': 0.8885031924584083}
# Processing model 3 for pdb_id: 5m01...
# {'pdb_id': '5m01', 'model_number': '3', 'global_plddt': 92.72640030674847, 'cdr1_A': 96.27000000000001, 'cdr2_A': 95.2201923076923, 'cdr3_A': 95.45373333333333, 'cdr1_B': 95.15434782608695, 'cdr2_B': 94.32181818181817, 'cdr3_B': 96.56535714285712, 'iptm_mean': 0.8560000000000001, 'iptm_tcrpmhc': 0.875, 'pdockq_AB': 0.482, 'pdockq_BA': 0.482, 'avgipae_A_AB': 0.6551879109151605, 'avgipae_B_AB': 0.5521880329806825, 'pdockq2_A_AB': 0.22878043733715392, 'pdockq2_A_BA': 0.9276506325378522, 'avgipae_A_BA': 0.9804492374013235, 'avgipae_B_BA': 0.9715577436744025, 'pdockq2_B_BA': 0.8845555624566142}
# Processing model 2 for pdb_id: 5m01...
# {'pdb_id': '5m01', 'model_number': '2', 'global_plddt': 92.74765797546011, 'cdr1_A': 96.20634615384614, 'cdr2_A': 95.10653846153846, 'cdr3_A': 95.37693333333333, 'cdr1_B': 95.02521739130434, 'cdr2_B': 94.1625, 'cdr3_B': 96.56952380952382, 'iptm_mean': 0.852, 'iptm_tcrpmhc': 0.8725, 'pdockq_AB': 0.476, 'pdockq_BA': 0.476, 'avgipae_A_AB': 0.6435125193571682, 'avgipae_B_AB': 0.544159370387267, 'pdockq2_A_AB': 0.21348936389962023, 'pdockq2_A_BA': 0.9296140578858293, 'avgipae_A_BA': 0.9809226392163881, 'avgipae_B_BA': 0.9720222606132186, 'pdockq2_B_BA': 0.8854845126630996}
# Processing model 2 for pdb_id: 6rsy...
# {'pdb_id': '6rsy', 'model_number': '2', 'global_plddt': 92.92943427620632, 'cdr1_A': 90.52620689655171, 'cdr2_A': 88.52081081081081, 'cdr3_A': 88.81271739130435, 'cdr1_B': 92.29272727272726, 'cdr2_B': 95.10039215686274, 'cdr3_B': 95.04022471910112, 'iptm_mean': 0.852, 'iptm_tcrpmhc': 0.865, 'pdockq_AB': 0.587, 'pdockq_BA': 0.587, 'avgipae_A_AB': 0.6399276053819607, 'avgipae_B_AB': 0.544405778092167, 'pdockq2_A_AB': 0.19006334387723123, 'pdockq2_A_BA': 0.8963266075075426, 'avgipae_A_BA': 0.9758862058973927, 'avgipae_B_BA': 0.9620610094305619, 'pdockq2_B_BA': 0.8123027787975178}
# Processing model 3 for pdb_id: 6rsy...
# {'pdb_id': '6rsy', 'model_number': '3', 'global_plddt': 92.95593102405083, 'cdr1_A': 90.26310344827586, 'cdr2_A': 87.84945945945948, 'cdr3_A': 88.0779347826087, 'cdr1_B': 92.28863636363636, 'cdr2_B': 94.94431372549019, 'cdr3_B': 94.47786516853934, 'iptm_mean': 0.852, 'iptm_tcrpmhc': 0.865, 'pdockq_AB': 0.588, 'pdockq_BA': 0.588, 'avgipae_A_AB': 0.6665072546134497, 'avgipae_B_AB': 0.5470557545178091, 'pdockq2_A_AB': 0.21806488110145608, 'pdockq2_A_BA': 0.8927263199998811, 'avgipae_A_BA': 0.9752468366299883, 'avgipae_B_BA': 0.9590374935458286, 'pdockq2_B_BA': 0.7958278122584145}
# Processing model 4 for pdb_id: 6rsy...
# {'pdb_id': '6rsy', 'model_number': '4', 'global_plddt': 93.06812887611557, 'cdr1_A': 90.73172413793102, 'cdr2_A': 88.44621621621623, 'cdr3_A': 88.80989130434783, 'cdr1_B': 92.47272727272728, 'cdr2_B': 95.1478431372549, 'cdr3_B': 94.86022471910111, 'iptm_mean': 0.858, 'iptm_tcrpmhc': 0.8674999999999999, 'pdockq_AB': 0.589, 'pdockq_BA': 0.589, 'avgipae_A_AB': 0.67727385364854, 'avgipae_B_AB': 0.5586371804024822, 'pdockq2_A_AB': 0.23576358536697056, 'pdockq2_A_BA': 0.8978525230183275, 'avgipae_A_BA': 0.9765069086881901, 'avgipae_B_BA': 0.9628945044711793, 'pdockq2_B_BA': 0.8132733579151933}
# Processing model 1 for pdb_id: 6rsy...
# {'pdb_id': '6rsy', 'model_number': '1', 'global_plddt': 92.99267584329148, 'cdr1_A': 90.41706896551723, 'cdr2_A': 88.3172972972973, 'cdr3_A': 87.90869565217392, 'cdr1_B': 92.26454545454544, 'cdr2_B': 94.96764705882352, 'cdr3_B': 94.54292134831462, 'iptm_mean': 0.858, 'iptm_tcrpmhc': 0.865, 'pdockq_AB': 0.581, 'pdockq_BA': 0.581, 'avgipae_A_AB': 0.6787033304927362, 'avgipae_B_AB': 0.5608755855866472, 'pdockq2_A_AB': 0.2333986891586413, 'pdockq2_A_BA': 0.894422987540828, 'avgipae_A_BA': 0.976231225775299, 'avgipae_B_BA': 0.9612672388898875, 'pdockq2_B_BA': 0.7997327104198582}
# Processing model 0 for pdb_id: 6rsy...
# {'pdb_id': '6rsy', 'model_number': '0', 'global_plddt': 92.98883981243382, 'cdr1_A': 90.36189655172413, 'cdr2_A': 88.14324324324325, 'cdr3_A': 88.6495652173913, 'cdr1_B': 92.28227272727273, 'cdr2_B': 94.69921568627451, 'cdr3_B': 94.67887640449439, 'iptm_mean': 0.858, 'iptm_tcrpmhc': 0.865, 'pdockq_AB': 0.597, 'pdockq_BA': 0.597, 'avgipae_A_AB': 0.680030934315576, 'avgipae_B_AB': 0.548605411247223, 'pdockq2_A_AB': 0.23823596413399417, 'pdockq2_A_BA': 0.8976673916982488, 'avgipae_A_BA': 0.9765006006161946, 'avgipae_B_BA': 0.9611732554173051, 'pdockq2_B_BA': 0.8066256663206498}
# Processing model 4 for pdb_id: 5e9d...
# {'pdb_id': '5e9d', 'model_number': '4', 'global_plddt': 93.56573125, 'cdr1_A': 90.96499999999999, 'cdr2_A': 96.25152173913041, 'cdr3_A': 92.67633333333335, 'cdr1_B': 94.23425531914894, 'cdr2_B': 94.82055555555556, 'cdr3_B': 94.80840000000002, 'iptm_mean': 0.8539999999999999, 'iptm_tcrpmhc': 0.87, 'pdockq_AB': 0.481, 'pdockq_BA': 0.481, 'avgipae_A_AB': 0.7407331935705853, 'avgipae_B_AB': 0.6094651591075638, 'pdockq2_A_AB': 0.36195136246430737, 'pdockq2_A_BA': 0.927517401187251, 'avgipae_A_BA': 0.9813648938347396, 'avgipae_B_BA': 0.9763692497333668, 'pdockq2_B_BA': 0.8860428981716326}
# Processing model 3 for pdb_id: 5e9d...
# {'pdb_id': '5e9d', 'model_number': '3', 'global_plddt': 93.6487875, 'cdr1_A': 90.87928571428571, 'cdr2_A': 96.1195652173913, 'cdr3_A': 92.60822222222222, 'cdr1_B': 94.26297872340425, 'cdr2_B': 94.60916666666668, 'cdr3_B': 94.795, 'iptm_mean': 0.85, 'iptm_tcrpmhc': 0.865, 'pdockq_AB': 0.472, 'pdockq_BA': 0.472, 'avgipae_A_AB': 0.7401880954193696, 'avgipae_B_AB': 0.5923665196432188, 'pdockq2_A_AB': 0.358852700911817, 'pdockq2_A_BA': 0.9248284680941636, 'avgipae_A_BA': 0.9806827565270217, 'avgipae_B_BA': 0.9734084710600814, 'pdockq2_B_BA': 0.8767741078670823}
# Processing model 2 for pdb_id: 5e9d...
# {'pdb_id': '5e9d', 'model_number': '2', 'global_plddt': 93.77154791666666, 'cdr1_A': 90.99047619047619, 'cdr2_A': 96.38347826086954, 'cdr3_A': 92.76133333333334, 'cdr1_B': 94.47297872340427, 'cdr2_B': 95.14722222222221, 'cdr3_B': 95.03500000000003, 'iptm_mean': 0.858, 'iptm_tcrpmhc': 0.8725, 'pdockq_AB': 0.467, 'pdockq_BA': 0.467, 'avgipae_A_AB': 0.7556260026482097, 'avgipae_B_AB': 0.6022829187296572, 'pdockq2_A_AB': 0.39175792973954304, 'pdockq2_A_BA': 0.9299254434445232, 'avgipae_A_BA': 0.9822939557892971, 'avgipae_B_BA': 0.9768267124155025, 'pdockq2_B_BA': 0.8886469409605179}
# Processing model 0 for pdb_id: 5e9d...
# {'pdb_id': '5e9d', 'model_number': '0', 'global_plddt': 93.64478333333334, 'cdr1_A': 90.78785714285715, 'cdr2_A': 96.245, 'cdr3_A': 92.18299999999999, 'cdr1_B': 94.07531914893617, 'cdr2_B': 94.56944444444446, 'cdr3_B': 94.42970000000001, 'iptm_mean': 0.8460000000000001, 'iptm_tcrpmhc': 0.86, 'pdockq_AB': 0.449, 'pdockq_BA': 0.449, 'avgipae_A_AB': 0.7391718580861331, 'avgipae_B_AB': 0.5844314290897588, 'pdockq2_A_AB': 0.3557918994289935, 'pdockq2_A_BA': 0.9238684864716155, 'avgipae_A_BA': 0.979962698871755, 'avgipae_B_BA': 0.9735044908964499, 'pdockq2_B_BA': 0.8752237937861981}
# Processing model 1 for pdb_id: 5e9d...
# {'pdb_id': '5e9d', 'model_number': '1', 'global_plddt': 93.56777708333334, 'cdr1_A': 90.83071428571427, 'cdr2_A': 96.1804347826087, 'cdr3_A': 92.4948888888889, 'cdr1_B': 94.09872340425531, 'cdr2_B': 94.56666666666666, 'cdr3_B': 94.697, 'iptm_mean': 0.85, 'iptm_tcrpmhc': 0.865, 'pdockq_AB': 0.472, 'pdockq_BA': 0.472, 'avgipae_A_AB': 0.7364882055369759, 'avgipae_B_AB': 0.5909055293918086, 'pdockq2_A_AB': 0.3525185022383893, 'pdockq2_A_BA': 0.9251255954110287, 'avgipae_A_BA': 0.9804106313487225, 'avgipae_B_BA': 0.9743362279105375, 'pdockq2_B_BA': 0.8794975748948655}
# Processing model 0 for pdb_id: 7dzm...
# {'pdb_id': '7dzm', 'model_number': '0', 'global_plddt': 91.84267647942326, 'cdr1_A': 86.40944444444447, 'cdr2_A': 87.15918918918919, 'cdr3_A': 89.17340425531914, 'cdr1_B': 92.71352941176471, 'cdr2_B': 91.82530612244899, 'cdr3_B': 90.80285714285714, 'iptm_mean': 0.808, 'iptm_tcrpmhc': 0.8025, 'pdockq_AB': 0.367, 'pdockq_BA': 0.367, 'avgipae_A_AB': 0.4412880033518779, 'avgipae_B_AB': 0.42800533946709346, 'pdockq2_A_AB': 0.04958954504843169, 'pdockq2_A_BA': 0.76396077537518, 'avgipae_A_BA': 0.94330572343692, 'avgipae_B_BA': 0.9347994265398882, 'pdockq2_B_BA': 0.657351777180282}
# Processing model 1 for pdb_id: 7dzm...
# {'pdb_id': '7dzm', 'model_number': '1', 'global_plddt': 92.04706818864524, 'cdr1_A': 87.12777777777777, 'cdr2_A': 88.11486486486487, 'cdr3_A': 89.43670212765957, 'cdr1_B': 92.78441176470587, 'cdr2_B': 91.9651020408163, 'cdr3_B': 90.6407142857143, 'iptm_mean': 0.8140000000000001, 'iptm_tcrpmhc': 0.81, 'pdockq_AB': 0.369, 'pdockq_BA': 0.369, 'avgipae_A_AB': 0.43822997071870506, 'avgipae_B_AB': 0.4335733808638288, 'pdockq2_A_AB': 0.04887652165624944, 'pdockq2_A_BA': 0.7723987993198926, 'avgipae_A_BA': 0.9467955266126578, 'avgipae_B_BA': 0.938851027588158, 'pdockq2_B_BA': 0.6691291493184228}
# Processing model 4 for pdb_id: 7dzm...
# {'pdb_id': '7dzm', 'model_number': '4', 'global_plddt': 92.07688044457795, 'cdr1_A': 87.85962962962961, 'cdr2_A': 88.60432432432432, 'cdr3_A': 90.3913829787234, 'cdr1_B': 92.98676470588236, 'cdr2_B': 91.94897959183673, 'cdr3_B': 90.96671428571432, 'iptm_mean': 0.82, 'iptm_tcrpmhc': 0.8175, 'pdockq_AB': 0.376, 'pdockq_BA': 0.376, 'avgipae_A_AB': 0.4551206924966587, 'avgipae_B_AB': 0.44868832133958886, 'pdockq2_A_AB': 0.05469885679901255, 'pdockq2_A_BA': 0.7884280931980091, 'avgipae_A_BA': 0.950634925402577, 'avgipae_B_BA': 0.941940255695051, 'pdockq2_B_BA': 0.6860530868266}
# Processing model 3 for pdb_id: 7dzm...
# {'pdb_id': '7dzm', 'model_number': '3', 'global_plddt': 91.97689095824572, 'cdr1_A': 87.47444444444444, 'cdr2_A': 87.21891891891893, 'cdr3_A': 89.82595744680853, 'cdr1_B': 92.98941176470588, 'cdr2_B': 91.96204081632654, 'cdr3_B': 91.28957142857143, 'iptm_mean': 0.8160000000000001, 'iptm_tcrpmhc': 0.81, 'pdockq_AB': 0.373, 'pdockq_BA': 0.373, 'avgipae_A_AB': 0.4410284898442439, 'avgipae_B_AB': 0.4058564566327244, 'pdockq2_A_AB': 0.05008879996080336, 'pdockq2_A_BA': 0.7749958394872674, 'avgipae_A_BA': 0.9465128605734046, 'avgipae_B_BA': 0.9390114371803449, 'pdockq2_B_BA': 0.675949163513414}
# Processing model 2 for pdb_id: 7dzm...
# {'pdb_id': '7dzm', 'model_number': '2', 'global_plddt': 91.91958095524181, 'cdr1_A': 86.75425925925926, 'cdr2_A': 87.55864864864866, 'cdr3_A': 89.02202127659574, 'cdr1_B': 92.14588235294116, 'cdr2_B': 91.00734693877548, 'cdr3_B': 90.10914285714284, 'iptm_mean': 0.806, 'iptm_tcrpmhc': 0.7925, 'pdockq_AB': 0.366, 'pdockq_BA': 0.366, 'avgipae_A_AB': 0.4429536741160039, 'avgipae_B_AB': 0.4232978199584187, 'pdockq2_A_AB': 0.0487885910808932, 'pdockq2_A_BA': 0.7358789057338797, 'avgipae_A_BA': 0.9357745839116902, 'avgipae_B_BA': 0.9237321069697763, 'pdockq2_B_BA': 0.6124008964497435}
